# %% [markdown]
# # Import Modules

# %% [markdown]
# ## Standard modules

# %%
import os
import json
import pickle as pkl

from collections import Counter

# %% [markdown]
# ## External modules

# %%
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

from sklearn.metrics import precision_score, \
                            recall_score, \
                            f1_score, \
                            roc_auc_score \
            
from tqdm import tqdm, trange
from pylab import rcParams



tqdm.pandas()
# %matplotlib inline
warnings.filterwarnings('ignore')
rcParams['figure.figsize'] = 10, 10
# Out:
# /opt/conda/lib/python3.7/site-packages/tqdm/std.py:701: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %% [markdown]
# ## Internal modules

# %%
import utils_scripts as utlis

# %% [markdown]
# # Constants

# %%
RANDOM_SEED = 17
np.random.seed(RANDOM_SEED)

ABS_PATH = '/kaggle/input/herbarium-2020-fgvc7/nybg2020/'

# %% [markdown]
# # Data EDA

# %%
def get_result_df(path, set_value):
    with open(os.path.join(ABS_PATH, set_value, 'metadata.json'), "r", encoding="ISO-8859-1") as file:
        metadata = json.load(file)
    
    for column_name, column in metadata.items():
        print(f'{column_name} - {len(column)} values')
        
    img_info = pd.DataFrame(metadata['images'])
    
    if set_value == 'train':
        annotation_info = pd.DataFrame(metadata['annotations']).drop(columns=['image_id'])
        img_info = img_info.merge(annotation_info, on='id')
    
    img_info['file_name'] = img_info['file_name'].progress_apply(lambda x : os.path.join(path, set_value, x))
    return img_info

# %%
submission_example = pd.read_csv('/kaggle/input/herbarium-2020-fgvc7/sample_submission.csv')
submission_example.tail()
# Out:
#             Id  Predicted
# 138287  138287          0
# 138288  138288          0
# 138289  138289          0
# 138290  138290          0
# 138291  138291          0

# %%
metadata_train = get_result_df(path=ABS_PATH, set_value='train')
metadata_train.head()
# Out:
# annotations - 1030747 values
# categories - 32094 values
# images - 1030747 values
# info - 6 values
# licenses - 1 values
# regions - 4 values
# 100%|██████████| 1030747/1030747 [00:04<00:00, 251398.45it/s]
#                                            file_name  height      id  license  \
# 0  /kaggle/input/herbarium-2020-fgvc7/nybg2020/tr...    1000  354106        1
# 1  /kaggle/input/herbarium-2020-fgvc7/nybg2020/tr...    1000  818566        1
# 2  /kaggle/input/herbarium-2020-fgvc7/nybg2020/tr...    1000  750704        1
# 3  /kaggle/input/herbarium-2020-fgvc7/nybg2020/tr...    1000  722381        1
# 4  /kaggle/input/herbarium-2020-fgvc7/nybg2020/tr...    1000  382783        1
#
#    width  category_id  region_id
# 0    661        15672          1
# 1    661        11524          1
# 2    661        11524          1
# 3    661        11467          1
# 4    661        15660          1

# %%
metadata_test = get_result_df(path=ABS_PATH, set_value='test')
metadata_test.head()
# Out:
# images - 138292 values
# info - 6 values
# licenses - 1 values
# 100%|██████████| 138292/138292 [00:00<00:00, 289892.23it/s]
#                                            file_name  height      id  license  \
# 0  /kaggle/input/herbarium-2020-fgvc7/nybg2020/te...    1000  104891        1
# 1  /kaggle/input/herbarium-2020-fgvc7/nybg2020/te...    1000   18029        1
# 2  /kaggle/input/herbarium-2020-fgvc7/nybg2020/te...    1000   35151        1
# 3  /kaggle/input/herbarium-2020-fgvc7/nybg2020/te...    1000  124144        1
# 4  /kaggle/input/herbarium-2020-fgvc7/nybg2020/te...    1000   24649        1
#
#    width
# 0    661
# 1    661
# 2    661
# 3    682
# 4    682

# %%
classes = sorted(list(metadata_train['category_id'].unique()))
classes == list(range(min(classes), len(classes) + 1))
# Out:
# False

# %%
metadata_train['category_id'].value_counts()

# %% [markdown]
# ## Label preprocessing

# %%
le_preprocessor = LabelEncoder()
le_preprocessor.fit(metadata_train['category_id'])
# Out:
# LabelEncoder()

# %%
metadata_train['category_id_le_preprocessed'] = le_preprocessor.transform(metadata_train['category_id'])

# %%
classes = sorted(list(metadata_train['category_id_le_preprocessed'].unique()))
classes == list(range(min(classes), len(classes)))
# Out:
# True

# %% [markdown]
# # Train Test Split

# %%
# train_indices, test_indices, _, _ = train_test_split(metadata_train.index, 
#                                                      metadata_train['category_id_le_preprocessed'],
#                                                      train_size=0.75, 
#                                                      random_state=RANDOM_SEED,                                                     
#                                                      shuffle=True, 
#                                                      stratify=metadata_train['category_id_le_preprocessed'])

# %%
grouped = metadata_train.groupby('category_id_le_preprocessed', as_index=False).count()

# %%
little_classes = grouped[grouped['id'] < 3]['category_id_le_preprocessed']

# %%
little_classes
# Out:
# 2            2
# 21          21
# 24          24
# 28          28
# 38          38
#          ...
# 32061    32061
# 32068    32068
# 32073    32073
# 32080    32080
# 32082    32082
# Name: category_id_le_preprocessed, Length: 3729, dtype: int64

# %%
train_indices, test_indices, _, _ = train_test_split(metadata_train.index, 
                                                     metadata_train['category_id_le_preprocessed'],
                                                     train_size=0.75, 
                                                     random_state=RANDOM_SEED,                                                     
                                                     shuffle=True)

# %%
train_data = metadata_train.loc[train_indices, :]
train_data.shape

train_data.reset_index(inplace=True)

# %%
test_data = metadata_train.loc[test_indices, :]
test_data.shape

test_data.reset_index(inplace=True)

# %%
test_indices, val_indices, _, _ = train_test_split(test_data.index, 
                                                   test_data['category_id_le_preprocessed'],
                                                   train_size=0.80, 
                                                   random_state=RANDOM_SEED,                                                     
                                                   shuffle=True)

# %%
val_data = test_data.loc[val_indices, :]
val_data.shape
val_data.reset_index(inplace=True)

# %%
test_data = test_data.loc[test_indices, :]
test_data.shape
test_data.reset_index(inplace=True)

# %% [markdown]
# ## Class weights

# %%
class_weights = Counter(train_data['category_id_le_preprocessed'])
class_weights = [item[1] for item in sorted(list(class_weights.items()), key=lambda x : x[0])]

# %% [markdown]
# # Model Development

# %%
import torch

# %%
from torch import Tensor
from torch.utils.data import DataLoader
from utils_scripts import Specimen_Dataset, \
                          Data_Pipeline, \
                          Resizer, \
                          Normalizer, \
                          ToTensor

# %%
data_pipe_obj = Data_Pipeline(
    Resizer(output_size=(256,256)),
    Normalizer(mean=[0.485, 0.456, 0.406],std=[0.229, 0.224, 0.225]),
    ToTensor()
)

# %%
train_dataset = Specimen_Dataset(dataset=train_data, set_value='train', transform=data_pipe_obj)
test_dataset = Specimen_Dataset(dataset=test_data, set_value='test', transform=data_pipe_obj)
val_dataset = Specimen_Dataset(dataset=val_data, set_value='val', transform=data_pipe_obj)
test_subm_dataset = Specimen_Dataset(dataset=metadata_test, set_value='test_submission', transform=data_pipe_obj)

# %%
print(f'train dataset : {len(train_dataset)}')
print(f'test dataset : {len(test_dataset)}')
print(f'val dataset : {len(val_dataset)}')
print(f'subm dataset : {len(test_subm_dataset)}')
# Out:
# train dataset : 773060
# test dataset : 206149
# val dataset : 51538
# subm dataset : 138292

# %%
BATCH_SIZE = 256
torch.manual_seed(RANDOM_SEED)
torch.cuda.manual_seed(RANDOM_SEED)

# %%
train_dataloader = DataLoader(dataset=train_dataset, shuffle=True, batch_size=BATCH_SIZE, num_workers = 8)
test_dataloader = DataLoader(dataset=test_dataset, shuffle=True, batch_size=BATCH_SIZE, num_workers = 8)
val_dataloader = DataLoader(dataset=val_dataset, shuffle=True, batch_size=BATCH_SIZE, num_workers = 8)
test_subm_dataloader = DataLoader(dataset=test_subm_dataset, shuffle=False, batch_size=BATCH_SIZE, num_workers = 8)

# %%
for batch_index, batch in enumerate(train_dataloader, 0):
    images, categories = batch['img'], batch['category_id']
    
    print(images.shape)
    print(categories.shape)
    
    break

# %%
metadata_train.columns
# Out:
# Index(['file_name', 'height', 'id', 'license', 'width', 'category_id',
#        'region_id', 'category_id_le_preprocessed'],
#       dtype='object')

# %%
metadata_train['height'].value_counts()
# Out:
# 1000    1030649
# 667          57
# 670           5
# 665           4
# 683           3
# 675           2
# 682           2
# 977           1
# 598           1
# 615           1
# 649           1
# 661           1
# 662           1
# 666           1
# 669           1
# 673           1
# 684           1
# 696           1
# 700           1
# 718           1
# 720           1
# 721           1
# 731           1
# 742           1
# 788           1
# 802           1
# 818           1
# 858           1
# 386           1
# 928           1
# 975           1
# 533           1
# Name: height, dtype: int64

# %%
metadata_train['width'].value_counts()
# Out:
# 682    219673
# 667    212347
# 676    190476
# 681     86647
# 678     76882
#         ...
# 964         1
# 655         1
# 648         1
# 645         1
# 595         1
# Name: width, Length: 181, dtype: int64

# %% [markdown]
# ## ResNet-18

# %%
from collections import namedtuple

# %%
from torch.optim import SGD, lr_scheduler
from torch.nn import Linear, CrossEntropyLoss
from torchvision.models import resnet18

# %%
NUM_OF_CLASSES = len(classes)
NUM_OF_EPOCHES = 1

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
device
# Out:
# device(type='cuda')

# %%
resnet18_model = resnet18(pretrained=True)
resnet18_model.fc = Linear(resnet18_model.fc.in_features, NUM_OF_CLASSES)

# %%
resnet18_model = resnet18_model.to(device)

loss_func = CrossEntropyLoss()
optimizer_sgd = SGD(resnet18_model.parameters(), lr=0.001, momentum=0.9)
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_sgd, step_size=7, gamma=0.1)

# %%
torch.cuda.empty_cache()

# %%
num_of_batches_train = len(train_dataset) // BATCH_SIZE
num_of_batches_val = len(val_dataset) // BATCH_SIZE
num_of_batches_test = len(test_dataset) // BATCH_SIZE
num_of_batches_subm = len(test_subm_dataset) // BATCH_SIZE

# %%
print(f'Train : {num_of_batches_train}')
print(f'Val : {num_of_batches_val}')
print(f'Test : {num_of_batches_test}')
print(f'Subm : {num_of_batches_subm}')
# Out:
# Train : 3019
# Val : 201
# Test : 805
# Subm : 540

# %%
for epoch_i in trange(1,NUM_OF_EPOCHES+1, desc='Epoches'):
    y_true, y_pred = torch.Tensor([]), torch.Tensor([])
    y_true_val, y_pred_val = torch.Tensor([]), torch.Tensor([])
    
    y_true, y_pred = y_true.to(device), y_pred.to(device)
    y_true_val, y_pred_val = y_true_val.to(device), y_pred_val.to(device)
    
    epoch_loss = 0.0
    resnet18_model.train()
    
    print('TRAIN Batches processing...')

    for batch_index, batch in enumerate(train_dataloader, 0):
                
        images, categories = batch['img'], batch['category_id']
        images, categories = images.to(device), categories.to(device)
        
        optimizer_sgd.zero_grad()
        
        outputs = resnet18_model(images)
        
        _, preds = torch.max(outputs, 1)
        
#         print(preds.shape)
        
        y_pred = torch.cat((y_pred, preds))
        y_true = torch.cat((y_true, categories))
        
        loss = loss_func(outputs, categories)
        epoch_loss += loss.item()

        loss.backward()
        optimizer_sgd.step()
        exp_lr_scheduler.step()
        
        print(f'{batch_index + 1}/{num_of_batches_train} total batches processed')
        
#         break

    print()
        
    resnet18_model.eval()
    
    print('Val Batches processing...')
    
    with torch.no_grad():
        for batch_index, batch in enumerate(val_dataloader, 0):
            
            images, categories = batch['img'], batch['category_id']
            images, categories = images.to(device), categories.to(device)
            
            outputs = resnet18_model(images)
            
            _, preds = torch.max(outputs,1)
            
            y_pred_val = torch.cat((y_pred_val, preds))
            y_true_val = torch.cat((y_true_val, categories))
            
            print(f'{batch_index + 1}/{num_of_batches_val} total batches processed')
            
#             break
            
    print(f'Epoch : {epoch_i}')
    print(f'Loss : {epoch_loss / (batch_index+1)}')
    print()
    print('Train : ')
    print(f"PRECISION : {precision_score(y_true.cpu().numpy().astype(int), y_pred.cpu().numpy().astype(int), average='macro')}")
    print(f"RECALL : {recall_score(y_true.cpu().numpy().astype(int), y_pred.cpu().numpy().astype(int), average='macro')}")
    print(f"F1-SCORE : {f1_score(y_true.cpu().numpy().astype(int), y_pred.cpu().numpy().astype(int), average='macro')}")
    
    print()
    print('Val : ')
    print(f"PRECISION : {precision_score(y_true_val.cpu().numpy().astype(int), y_pred_val.cpu().numpy().astype(int), average='macro')}")
    print(f"RECALL : {recall_score(y_true_val.cpu().numpy().astype(int), y_pred_val.cpu().numpy().astype(int), average='macro')}")
    print(f"F1-SCORE : {f1_score(y_true_val.cpu().numpy().astype(int), y_pred_val.cpu().numpy().astype(int), average='macro')}")
    print()
        
        
torch.save(resnet18_model.state_dict(), '/kaggle/working/resnet18_V2.pth')
# Out:
# Epoches:   0%|          | 0/1 [00:00<?, ?it/s]
# TRAIN Batches processing...
# 1/3019 total batches processed
# 2/3019 total batches processed
# 3/3019 total batches processed
# 4/3019 total batches processed
# 5/3019 total batches processed
# 6/3019 total batches processed
# 7/3019 total batches processed
# 8/3019 total batches processed
# 9/3019 total batches processed
# 10/3019 total batches processed
# 11/3019 total batches processed
# 12/3019 total batches processed
# 13/3019 total batches processed
# 14/3019 total batches processed
# 15/3019 total batches processed
# 16/3019 total batches processed
# 17/3019 total batches processed
# 18/3019 total batches processed
# 19/3019 total batches processed
# 20/3019 total batches processed
# 21/3019 total batches processed
# 22/3019 total batches processed
# 23/3019 total batches processed
# 24/3019 total batches processed
# 25/3019 total batches processed
# 26/3019 total batches processed
# 27/3019 total batches processed
# 28/3019 total batches processed
# 29/3019 total batches processed
# 30/3019 total batches processed
# 31/3019 total batches processed
# 32/3019 total batches processed
# 33/3019 total batches processed
# 34/3019 total batches processed
# 35/3019 total batches processed
# 36/3019 total batches processed
# 37/3019 total batches processed
# 38/3019 total batches processed
# 39/3019 total batches processed
# 40/3019 total batches processed
# 41/3019 total batches processed
# 42/3019 total batches processed
# 43/3019 total batches processed
# 44/3019 total batches processed
# 45/3019 total batches processed
# 46/3019 total batches processed
# 47/3019 total batches processed
# 48/3019 total batches processed
# 49/3019 total batches processed
# 50/3019 total batches processed
# 51/3019 total batches processed
# 52/3019 total batches processed
# 53/3019 total batches processed
# 54/3019 total batches processed
# 55/3019 total batches processed
# 56/3019 total batches processed
# 57/3019 total batches processed
# 58/3019 total batches processed
# 59/3019 total batches processed
# 60/3019 total batches processed
# 61/3019 total batches processed
# 62/3019 total batches processed
# 63/3019 total batches processed
# 64/3019 total batches processed
# 65/3019 total batches processed
# 66/3019 total batches processed
# 67/3019 total batches processed
# 68/3019 total batches processed
# 69/3019 total batches processed
# 70/3019 total batches processed
# 71/3019 total batches processed
# 72/3019 total batches processed
# 73/3019 total batches processed
# 74/3019 total batches processed
# 75/3019 total batches processed
# 76/3019 total batches processed
# 77/3019 total batches processed
# 78/3019 total batches processed
# 79/3019 total batches processed
# 80/3019 total batches processed
# 81/3019 total batches processed
# 82/3019 total batches processed
# 83/3019 total batches processed
# 84/3019 total batches processed
# 85/3019 total batches processed
# 86/3019 total batches processed
# 87/3019 total batches processed
# 88/3019 total batches processed
# 89/3019 total batches processed
# 90/3019 total batches processed
# 91/3019 total batches processed
# 92/3019 total batches processed
# 93/3019 total batches processed
# 94/3019 total batches processed
# 95/3019 total batches processed
# 96/3019 total batches processed
# 97/3019 total batches processed
# 98/3019 total batches processed
# 99/3019 total batches processed
# 100/3019 total batches processed
# 101/3019 total batches processed
# 102/3019 total batches processed
# 103/3019 total batches processed
# 104/3019 total batches processed
# 105/3019 total batches processed
# 106/3019 total batches processed
# 107/3019 total batches processed
# 108/3019 total batches processed
# 109/3019 total batches processed
# 110/3019 total batches processed
# 111/3019 total batches processed
# 112/3019 total batches processed
# 113/3019 total batches processed
# 114/3019 total batches processed
# 115/3019 total batches processed
# 116/3019 total batches processed
# 117/3019 total batches processed
# 118/3019 total batches processed
# 119/3019 total batches processed
# 120/3019 total batches processed
# 121/3019 total batches processed
# 122/3019 total batches processed
# 123/3019 total batches processed
# 124/3019 total batches processed
# 125/3019 total batches processed
# 126/3019 total batches processed
# 127/3019 total batches processed
# 128/3019 total batches processed
# 129/3019 total batches processed
# 130/3019 total batches processed
# 131/3019 total batches processed
# 132/3019 total batches processed
# 133/3019 total batches processed
# 134/3019 total batches processed
# 135/3019 total batches processed
# 136/3019 total batches processed
# 137/3019 total batches processed
# 138/3019 total batches processed
# 139/3019 total batches processed
# 140/3019 total batches processed
# 141/3019 total batches processed
# 142/3019 total batches processed
# 143/3019 total batches processed
# 144/3019 total batches processed
# 145/3019 total batches processed
# 146/3019 total batches processed
# 147/3019 total batches processed
# 148/3019 total batches processed
# 149/3019 total batches processed
# 150/3019 total batches processed
# 151/3019 total batches processed
# 152/3019 total batches processed
# 153/3019 total batches processed
# 154/3019 total batches processed
# 155/3019 total batches processed
# 156/3019 total batches processed
# 157/3019 total batches processed
# 158/3019 total batches processed
# 159/3019 total batches processed
# 160/3019 total batches processed
# 161/3019 total batches processed
# 162/3019 total batches processed
# 163/3019 total batches processed
# 164/3019 total batches processed
# 165/3019 total batches processed
# 166/3019 total batches processed
# 167/3019 total batches processed
# 168/3019 total batches processed
# 169/3019 total batches processed
# 170/3019 total batches processed
# 171/3019 total batches processed
# 172/3019 total batches processed
# 173/3019 total batches processed
# 174/3019 total batches processed
# 175/3019 total batches processed
# 176/3019 total batches processed
# 177/3019 total batches processed
# 178/3019 total batches processed
# 179/3019 total batches processed
# 180/3019 total batches processed
# 181/3019 total batches processed
# 182/3019 total batches processed
# 183/3019 total batches processed
# 184/3019 total batches processed
# 185/3019 total batches processed
# 186/3019 total batches processed
# 187/3019 total batches processed
# 188/3019 total batches processed
# 189/3019 total batches processed
# 190/3019 total batches processed
# 191/3019 total batches processed
# 192/3019 total batches processed
# 193/3019 total batches processed
# 194/3019 total batches processed
# 195/3019 total batches processed
# 196/3019 total batches processed
# 197/3019 total batches processed
# 198/3019 total batches processed
# 199/3019 total batches processed
# 200/3019 total batches processed
# 201/3019 total batches processed
# 202/3019 total batches processed
# 203/3019 total batches processed
# 204/3019 total batches processed
# 205/3019 total batches processed
# 206/3019 total batches processed
# 207/3019 total batches processed
# 208/3019 total batches processed
# 209/3019 total batches processed
# 210/3019 total batches processed
# 211/3019 total batches processed
# 212/3019 total batches processed
# 213/3019 total batches processed
# 214/3019 total batches processed
# 215/3019 total batches processed
# 216/3019 total batches processed
# 217/3019 total batches processed
# 218/3019 total batches processed
# 219/3019 total batches processed
# 220/3019 total batches processed
# 221/3019 total batches processed
# 222/3019 total batches processed
# 223/3019 total batches processed
# 224/3019 total batches processed
# 225/3019 total batches processed
# 226/3019 total batches processed
# 227/3019 total batches processed
# 228/3019 total batches processed
# 229/3019 total batches processed
# 230/3019 total batches processed
# 231/3019 total batches processed
# 232/3019 total batches processed
# 233/3019 total batches processed
# 234/3019 total batches processed
# 235/3019 total batches processed
# 236/3019 total batches processed
# 237/3019 total batches processed
# 238/3019 total batches processed
# 239/3019 total batches processed
# 240/3019 total batches processed
# 241/3019 total batches processed
# 242/3019 total batches processed
# 243/3019 total batches processed
# 244/3019 total batches processed
# 245/3019 total batches processed
# 246/3019 total batches processed
# 247/3019 total batches processed
# 248/3019 total batches processed
# 249/3019 total batches processed
# 250/3019 total batches processed
# 251/3019 total batches processed
# 252/3019 total batches processed
# 253/3019 total batches processed
# 254/3019 total batches processed
# 255/3019 total batches processed
# 256/3019 total batches processed
# 257/3019 total batches processed
# 258/3019 total batches processed
# 259/3019 total batches processed
# 260/3019 total batches processed
# 261/3019 total batches processed
# 262/3019 total batches processed
# 263/3019 total batches processed
# 264/3019 total batches processed
# 265/3019 total batches processed
# 266/3019 total batches processed
# 267/3019 total batches processed
# 268/3019 total batches processed
# 269/3019 total batches processed
# 270/3019 total batches processed
# 271/3019 total batches processed
# 272/3019 total batches processed
# 273/3019 total batches processed
# 274/3019 total batches processed
# 275/3019 total batches processed
# 276/3019 total batches processed
# 277/3019 total batches processed
# 278/3019 total batches processed
# 279/3019 total batches processed
# 280/3019 total batches processed
# 281/3019 total batches processed
# 282/3019 total batches processed
# 283/3019 total batches processed
# 284/3019 total batches processed
# 285/3019 total batches processed
# 286/3019 total batches processed
# 287/3019 total batches processed
# 288/3019 total batches processed
# 289/3019 total batches processed
# 290/3019 total batches processed
# 291/3019 total batches processed
# 292/3019 total batches processed
# 293/3019 total batches processed
# 294/3019 total batches processed
# 295/3019 total batches processed
# 296/3019 total batches processed
# 297/3019 total batches processed
# 298/3019 total batches processed
# 299/3019 total batches processed
# 300/3019 total batches processed
# 301/3019 total batches processed
# 302/3019 total batches processed
# 303/3019 total batches processed
# 304/3019 total batches processed
# 305/3019 total batches processed
# 306/3019 total batches processed
# 307/3019 total batches processed
# 308/3019 total batches processed
# 309/3019 total batches processed
# 310/3019 total batches processed
# 311/3019 total batches processed
# 312/3019 total batches processed
# 313/3019 total batches processed
# 314/3019 total batches processed
# 315/3019 total batches processed
# 316/3019 total batches processed
# 317/3019 total batches processed
# 318/3019 total batches processed
# 319/3019 total batches processed
# 320/3019 total batches processed
# 321/3019 total batches processed
# 322/3019 total batches processed
# 323/3019 total batches processed
# 324/3019 total batches processed
# 325/3019 total batches processed
# 326/3019 total batches processed
# 327/3019 total batches processed
# 328/3019 total batches processed
# 329/3019 total batches processed
# 330/3019 total batches processed
# 331/3019 total batches processed
# 332/3019 total batches processed
# 333/3019 total batches processed
# 334/3019 total batches processed
# 335/3019 total batches processed
# 336/3019 total batches processed
# 337/3019 total batches processed
# 338/3019 total batches processed
# 339/3019 total batches processed
# 340/3019 total batches processed
# 341/3019 total batches processed
# 342/3019 total batches processed
# 343/3019 total batches processed
# 344/3019 total batches processed
# 345/3019 total batches processed
# 346/3019 total batches processed
# 347/3019 total batches processed
# 348/3019 total batches processed
# 349/3019 total batches processed
# 350/3019 total batches processed
# 351/3019 total batches processed
# 352/3019 total batches processed
# 353/3019 total batches processed
# 354/3019 total batches processed
# 355/3019 total batches processed
# 356/3019 total batches processed
# 357/3019 total batches processed
# 358/3019 total batches processed
# 359/3019 total batches processed
# 360/3019 total batches processed
# 361/3019 total batches processed
# 362/3019 total batches processed
# 363/3019 total batches processed
# 364/3019 total batches processed
# 365/3019 total batches processed
# 366/3019 total batches processed
# 367/3019 total batches processed
# 368/3019 total batches processed
# 369/3019 total batches processed
# 370/3019 total batches processed
# 371/3019 total batches processed
# 372/3019 total batches processed
# 373/3019 total batches processed
# 374/3019 total batches processed
# 375/3019 total batches processed
# 376/3019 total batches processed
# 377/3019 total batches processed
# 378/3019 total batches processed
# 379/3019 total batches processed
# 380/3019 total batches processed
# 381/3019 total batches processed
# 382/3019 total batches processed
# 383/3019 total batches processed
# 384/3019 total batches processed
# 385/3019 total batches processed
# 386/3019 total batches processed
# 387/3019 total batches processed
# 388/3019 total batches processed
# 389/3019 total batches processed
# 390/3019 total batches processed
# 391/3019 total batches processed
# 392/3019 total batches processed
# 393/3019 total batches processed
# 394/3019 total batches processed
# 395/3019 total batches processed
# 396/3019 total batches processed
# 397/3019 total batches processed
# 398/3019 total batches processed
# 399/3019 total batches processed
# 400/3019 total batches processed
# 401/3019 total batches processed
# 402/3019 total batches processed
# 403/3019 total batches processed
# 404/3019 total batches processed
# 405/3019 total batches processed
# 406/3019 total batches processed
# 407/3019 total batches processed
# 408/3019 total batches processed
# 409/3019 total batches processed
# 410/3019 total batches processed
# 411/3019 total batches processed
# 412/3019 total batches processed
# 413/3019 total batches processed
# 414/3019 total batches processed
# 415/3019 total batches processed
# 416/3019 total batches processed
# 417/3019 total batches processed
# 418/3019 total batches processed
# 419/3019 total batches processed
# 420/3019 total batches processed
# 421/3019 total batches processed
# 422/3019 total batches processed
# 423/3019 total batches processed
# 424/3019 total batches processed
# 425/3019 total batches processed
# 426/3019 total batches processed
# 427/3019 total batches processed
# 428/3019 total batches processed
# 429/3019 total batches processed
# 430/3019 total batches processed
# 431/3019 total batches processed
# 432/3019 total batches processed
# 433/3019 total batches processed
# 434/3019 total batches processed
# 435/3019 total batches processed
# 436/3019 total batches processed
# 437/3019 total batches processed
# 438/3019 total batches processed
# 439/3019 total batches processed
# 440/3019 total batches processed
# 441/3019 total batches processed
# 442/3019 total batches processed
# 443/3019 total batches processed
# 444/3019 total batches processed
# 445/3019 total batches processed
# 446/3019 total batches processed
# 447/3019 total batches processed
# 448/3019 total batches processed
# 449/3019 total batches processed
# 450/3019 total batches processed
# 451/3019 total batches processed
# 452/3019 total batches processed
# 453/3019 total batches processed
# 454/3019 total batches processed
# 455/3019 total batches processed
# 456/3019 total batches processed
# 457/3019 total batches processed
# 458/3019 total batches processed
# 459/3019 total batches processed
# 460/3019 total batches processed
# 461/3019 total batches processed
# 462/3019 total batches processed
# 463/3019 total batches processed
# 464/3019 total batches processed
# 465/3019 total batches processed
# 466/3019 total batches processed
# 467/3019 total batches processed
# 468/3019 total batches processed
# 469/3019 total batches processed
# 470/3019 total batches processed
# 471/3019 total batches processed
# 472/3019 total batches processed
# 473/3019 total batches processed
# 474/3019 total batches processed
# 475/3019 total batches processed
# 476/3019 total batches processed
# 477/3019 total batches processed
# 478/3019 total batches processed
# 479/3019 total batches processed
# 480/3019 total batches processed
# 481/3019 total batches processed
# 482/3019 total batches processed
# 483/3019 total batches processed
# 484/3019 total batches processed
# 485/3019 total batches processed
# 486/3019 total batches processed
# 487/3019 total batches processed
# 488/3019 total batches processed
# 489/3019 total batches processed
# 490/3019 total batches processed
# 491/3019 total batches processed
# 492/3019 total batches processed
# 493/3019 total batches processed
# 494/3019 total batches processed
# 495/3019 total batches processed
# 496/3019 total batches processed
# 497/3019 total batches processed
# 498/3019 total batches processed
# 499/3019 total batches processed
# 500/3019 total batches processed
# 501/3019 total batches processed
# 502/3019 total batches processed
# 503/3019 total batches processed
# 504/3019 total batches processed
# 505/3019 total batches processed
# 506/3019 total batches processed
# 507/3019 total batches processed
# 508/3019 total batches processed
# 509/3019 total batches processed
# 510/3019 total batches processed
# 511/3019 total batches processed
# 512/3019 total batches processed
# 513/3019 total batches processed
# 514/3019 total batches processed
# 515/3019 total batches processed
# 516/3019 total batches processed
# 517/3019 total batches processed
# 518/3019 total batches processed
# 519/3019 total batches processed
# 520/3019 total batches processed
# 521/3019 total batches processed
# 522/3019 total batches processed
# 523/3019 total batches processed
# 524/3019 total batches processed
# 525/3019 total batches processed
# 526/3019 total batches processed
# 527/3019 total batches processed
# 528/3019 total batches processed
# 529/3019 total batches processed
# 530/3019 total batches processed
# 531/3019 total batches processed
# 532/3019 total batches processed
# 533/3019 total batches processed
# 534/3019 total batches processed
# 535/3019 total batches processed
# 536/3019 total batches processed
# 537/3019 total batches processed
# 538/3019 total batches processed
# 539/3019 total batches processed
# 540/3019 total batches processed
# 541/3019 total batches processed
# 542/3019 total batches processed
# 543/3019 total batches processed
# 544/3019 total batches processed
# 545/3019 total batches processed
# 546/3019 total batches processed
# 547/3019 total batches processed
# 548/3019 total batches processed
# 549/3019 total batches processed
# 550/3019 total batches processed
# 551/3019 total batches processed
# 552/3019 total batches processed
# 553/3019 total batches processed
# 554/3019 total batches processed
# 555/3019 total batches processed
# 556/3019 total batches processed
# 557/3019 total batches processed
# 558/3019 total batches processed
# 559/3019 total batches processed
# 560/3019 total batches processed
# 561/3019 total batches processed
# 562/3019 total batches processed
# 563/3019 total batches processed
# 564/3019 total batches processed
# 565/3019 total batches processed
# 566/3019 total batches processed
# 567/3019 total batches processed
# 568/3019 total batches processed
# 569/3019 total batches processed
# 570/3019 total batches processed
# 571/3019 total batches processed
# 572/3019 total batches processed
# 573/3019 total batches processed
# 574/3019 total batches processed
# 575/3019 total batches processed
# 576/3019 total batches processed
# 577/3019 total batches processed
# 578/3019 total batches processed
# 579/3019 total batches processed
# 580/3019 total batches processed
# 581/3019 total batches processed
# 582/3019 total batches processed
# 583/3019 total batches processed
# 584/3019 total batches processed
# 585/3019 total batches processed
# 586/3019 total batches processed
# 587/3019 total batches processed
# 588/3019 total batches processed
# 589/3019 total batches processed
# 590/3019 total batches processed
# 591/3019 total batches processed
# 592/3019 total batches processed
# 593/3019 total batches processed
# 594/3019 total batches processed
# 595/3019 total batches processed
# 596/3019 total batches processed
# 597/3019 total batches processed
# 598/3019 total batches processed
# 599/3019 total batches processed
# 600/3019 total batches processed
# 601/3019 total batches processed
# 602/3019 total batches processed
# 603/3019 total batches processed
# 604/3019 total batches processed
# 605/3019 total batches processed
# 606/3019 total batches processed
# 607/3019 total batches processed
# 608/3019 total batches processed
# 609/3019 total batches processed
# 610/3019 total batches processed
# 611/3019 total batches processed
# 612/3019 total batches processed
# 613/3019 total batches processed
# 614/3019 total batches processed
# 615/3019 total batches processed
# 616/3019 total batches processed
# 617/3019 total batches processed
# 618/3019 total batches processed
# 619/3019 total batches processed
# 620/3019 total batches processed
# 621/3019 total batches processed
# 622/3019 total batches processed
# 623/3019 total batches processed
# 624/3019 total batches processed
# 625/3019 total batches processed
# 626/3019 total batches processed
# 627/3019 total batches processed
# 628/3019 total batches processed
# 629/3019 total batches processed
# 630/3019 total batches processed
# 631/3019 total batches processed
# 632/3019 total batches processed
# 633/3019 total batches processed
# 634/3019 total batches processed
# 635/3019 total batches processed
# 636/3019 total batches processed
# 637/3019 total batches processed
# 638/3019 total batches processed
# 639/3019 total batches processed
# 640/3019 total batches processed
# 641/3019 total batches processed
# 642/3019 total batches processed
# 643/3019 total batches processed
# 644/3019 total batches processed
# 645/3019 total batches processed
# 646/3019 total batches processed
# 647/3019 total batches processed
# 648/3019 total batches processed
# 649/3019 total batches processed
# 650/3019 total batches processed
# 651/3019 total batches processed
# 652/3019 total batches processed
# 653/3019 total batches processed
# 654/3019 total batches processed
# 655/3019 total batches processed
# 656/3019 total batches processed
# 657/3019 total batches processed
# 658/3019 total batches processed
# 659/3019 total batches processed
# 660/3019 total batches processed
# 661/3019 total batches processed
# 662/3019 total batches processed
# 663/3019 total batches processed
# 664/3019 total batches processed
# 665/3019 total batches processed
# 666/3019 total batches processed
# 667/3019 total batches processed
# 668/3019 total batches processed
# 669/3019 total batches processed
# 670/3019 total batches processed
# 671/3019 total batches processed
# 672/3019 total batches processed
# 673/3019 total batches processed
# 674/3019 total batches processed
# 675/3019 total batches processed
# 676/3019 total batches processed
# 677/3019 total batches processed
# 678/3019 total batches processed
# 679/3019 total batches processed
# 680/3019 total batches processed
# 681/3019 total batches processed
# 682/3019 total batches processed
# 683/3019 total batches processed
# 684/3019 total batches processed
# 685/3019 total batches processed
# 686/3019 total batches processed
# 687/3019 total batches processed
# 688/3019 total batches processed
# 689/3019 total batches processed
# 690/3019 total batches processed
# 691/3019 total batches processed
# 692/3019 total batches processed
# 693/3019 total batches processed
# 694/3019 total batches processed
# 695/3019 total batches processed
# 696/3019 total batches processed
# 697/3019 total batches processed
# 698/3019 total batches processed
# 699/3019 total batches processed
# 700/3019 total batches processed
# 701/3019 total batches processed
# 702/3019 total batches processed
# 703/3019 total batches processed
# 704/3019 total batches processed
# 705/3019 total batches processed
# 706/3019 total batches processed
# 707/3019 total batches processed
# 708/3019 total batches processed
# 709/3019 total batches processed
# 710/3019 total batches processed
# 711/3019 total batches processed
# 712/3019 total batches processed
# 713/3019 total batches processed
# 714/3019 total batches processed
# 715/3019 total batches processed
# 716/3019 total batches processed
# 717/3019 total batches processed
# 718/3019 total batches processed
# 719/3019 total batches processed
# 720/3019 total batches processed
# 721/3019 total batches processed
# 722/3019 total batches processed
# 723/3019 total batches processed
# 724/3019 total batches processed
# 725/3019 total batches processed
# 726/3019 total batches processed
# 727/3019 total batches processed
# 728/3019 total batches processed
# 729/3019 total batches processed
# 730/3019 total batches processed
# 731/3019 total batches processed
# 732/3019 total batches processed
# 733/3019 total batches processed
# 734/3019 total batches processed
# 735/3019 total batches processed
# 736/3019 total batches processed
# 737/3019 total batches processed
# 738/3019 total batches processed
# 739/3019 total batches processed
# 740/3019 total batches processed
# 741/3019 total batches processed
# 742/3019 total batches processed
# 743/3019 total batches processed
# 744/3019 total batches processed
# 745/3019 total batches processed
# 746/3019 total batches processed
# 747/3019 total batches processed
# 748/3019 total batches processed
# 749/3019 total batches processed
# 750/3019 total batches processed
# 751/3019 total batches processed
# 752/3019 total batches processed
# 753/3019 total batches processed
# 754/3019 total batches processed
# 755/3019 total batches processed
# 756/3019 total batches processed
# 757/3019 total batches processed
# 758/3019 total batches processed
# 759/3019 total batches processed
# 760/3019 total batches processed
# 761/3019 total batches processed
# 762/3019 total batches processed
# 763/3019 total batches processed
# 764/3019 total batches processed
# 765/3019 total batches processed
# 766/3019 total batches processed
# 767/3019 total batches processed
# 768/3019 total batches processed
# 769/3019 total batches processed
# 770/3019 total batches processed
# 771/3019 total batches processed
# 772/3019 total batches processed
# 773/3019 total batches processed
# 774/3019 total batches processed
# 775/3019 total batches processed
# 776/3019 total batches processed
# 777/3019 total batches processed
# 778/3019 total batches processed
# 779/3019 total batches processed
# 780/3019 total batches processed
# 781/3019 total batches processed
# 782/3019 total batches processed
# 783/3019 total batches processed
# 784/3019 total batches processed
# 785/3019 total batches processed
# 786/3019 total batches processed
# 787/3019 total batches processed
# 788/3019 total batches processed
# 789/3019 total batches processed
# 790/3019 total batches processed
# 791/3019 total batches processed
# 792/3019 total batches processed
# 793/3019 total batches processed
# 794/3019 total batches processed
# 795/3019 total batches processed
# 796/3019 total batches processed
# 797/3019 total batches processed
# 798/3019 total batches processed
# 799/3019 total batches processed
# 800/3019 total batches processed
# 801/3019 total batches processed
# 802/3019 total batches processed
# 803/3019 total batches processed
# 804/3019 total batches processed
# 805/3019 total batches processed
# 806/3019 total batches processed
# 807/3019 total batches processed
# 808/3019 total batches processed
# 809/3019 total batches processed
# 810/3019 total batches processed
# 811/3019 total batches processed
# 812/3019 total batches processed
# 813/3019 total batches processed
# 814/3019 total batches processed
# 815/3019 total batches processed
# 816/3019 total batches processed
# 817/3019 total batches processed
# 818/3019 total batches processed
# 819/3019 total batches processed
# 820/3019 total batches processed
# 821/3019 total batches processed
# 822/3019 total batches processed
# 823/3019 total batches processed
# 824/3019 total batches processed
# 825/3019 total batches processed
# 826/3019 total batches processed
# 827/3019 total batches processed
# 828/3019 total batches processed
# 829/3019 total batches processed
# 830/3019 total batches processed
# 831/3019 total batches processed
# 832/3019 total batches processed
# 833/3019 total batches processed
# 834/3019 total batches processed
# 835/3019 total batches processed
# 836/3019 total batches processed
# 837/3019 total batches processed
# 838/3019 total batches processed
# 839/3019 total batches processed
# 840/3019 total batches processed
# 841/3019 total batches processed
# 842/3019 total batches processed
# 843/3019 total batches processed
# 844/3019 total batches processed
# 845/3019 total batches processed
# 846/3019 total batches processed
# 847/3019 total batches processed
# 848/3019 total batches processed
# 849/3019 total batches processed
# 850/3019 total batches processed
# 851/3019 total batches processed
# 852/3019 total batches processed
# 853/3019 total batches processed
# 854/3019 total batches processed
# 855/3019 total batches processed
# 856/3019 total batches processed
# 857/3019 total batches processed
# 858/3019 total batches processed
# 859/3019 total batches processed
# 860/3019 total batches processed
# 861/3019 total batches processed
# 862/3019 total batches processed
# 863/3019 total batches processed
# 864/3019 total batches processed
# 865/3019 total batches processed
# 866/3019 total batches processed
# 867/3019 total batches processed
# 868/3019 total batches processed
# 869/3019 total batches processed
# 870/3019 total batches processed
# 871/3019 total batches processed
# 872/3019 total batches processed
# 873/3019 total batches processed
# 874/3019 total batches processed
# 875/3019 total batches processed
# 876/3019 total batches processed
# 877/3019 total batches processed
# 878/3019 total batches processed
# 879/3019 total batches processed
# 880/3019 total batches processed
# 881/3019 total batches processed
# 882/3019 total batches processed
# 883/3019 total batches processed
# 884/3019 total batches processed
# 885/3019 total batches processed
# 886/3019 total batches processed
# 887/3019 total batches processed
# 888/3019 total batches processed
# 889/3019 total batches processed
# 890/3019 total batches processed
# 891/3019 total batches processed
# 892/3019 total batches processed
# 893/3019 total batches processed
# 894/3019 total batches processed
# 895/3019 total batches processed
# 896/3019 total batches processed
# 897/3019 total batches processed
# 898/3019 total batches processed
# 899/3019 total batches processed
# 900/3019 total batches processed
# 901/3019 total batches processed
# 902/3019 total batches processed
# 903/3019 total batches processed
# 904/3019 total batches processed
# 905/3019 total batches processed
# 906/3019 total batches processed
# 907/3019 total batches processed
# 908/3019 total batches processed
# 909/3019 total batches processed
# 910/3019 total batches processed
# 911/3019 total batches processed
# 912/3019 total batches processed
# 913/3019 total batches processed
# 914/3019 total batches processed
# 915/3019 total batches processed
# 916/3019 total batches processed
# 917/3019 total batches processed
# 918/3019 total batches processed
# 919/3019 total batches processed
# 920/3019 total batches processed
# 921/3019 total batches processed
# 922/3019 total batches processed
# 923/3019 total batches processed
# 924/3019 total batches processed
# 925/3019 total batches processed
# 926/3019 total batches processed
# 927/3019 total batches processed
# 928/3019 total batches processed
# 929/3019 total batches processed
# 930/3019 total batches processed
# 931/3019 total batches processed
# 932/3019 total batches processed
# 933/3019 total batches processed
# 934/3019 total batches processed
# 935/3019 total batches processed
# 936/3019 total batches processed
# 937/3019 total batches processed
# 938/3019 total batches processed
# 939/3019 total batches processed
# 940/3019 total batches processed
# 941/3019 total batches processed
# 942/3019 total batches processed
# 943/3019 total batches processed
# 944/3019 total batches processed
# 945/3019 total batches processed
# 946/3019 total batches processed
# 947/3019 total batches processed
# 948/3019 total batches processed
# 949/3019 total batches processed
# 950/3019 total batches processed
# 951/3019 total batches processed
# 952/3019 total batches processed
# 953/3019 total batches processed
# 954/3019 total batches processed
# 955/3019 total batches processed
# 956/3019 total batches processed
# 957/3019 total batches processed
# 958/3019 total batches processed
# 959/3019 total batches processed
# 960/3019 total batches processed
# 961/3019 total batches processed
# 962/3019 total batches processed
# 963/3019 total batches processed
# 964/3019 total batches processed
# 965/3019 total batches processed
# 966/3019 total batches processed
# 967/3019 total batches processed
# 968/3019 total batches processed
# 969/3019 total batches processed
# 970/3019 total batches processed
# 971/3019 total batches processed
# 972/3019 total batches processed
# 973/3019 total batches processed
# 974/3019 total batches processed
# 975/3019 total batches processed
# 976/3019 total batches processed
# 977/3019 total batches processed
# 978/3019 total batches processed
# 979/3019 total batches processed
# 980/3019 total batches processed
# 981/3019 total batches processed
# 982/3019 total batches processed
# 983/3019 total batches processed
# 984/3019 total batches processed
# 985/3019 total batches processed
# 986/3019 total batches processed
# 987/3019 total batches processed
# 988/3019 total batches processed
# 989/3019 total batches processed
# 990/3019 total batches processed
# 991/3019 total batches processed
# 992/3019 total batches processed
# 993/3019 total batches processed
# 994/3019 total batches processed
# 995/3019 total batches processed
# 996/3019 total batches processed
# 997/3019 total batches processed
# 998/3019 total batches processed
# 999/3019 total batches processed
# 1000/3019 total batches processed
# 1001/3019 total batches processed
# 1002/3019 total batches processed
# 1003/3019 total batches processed
# 1004/3019 total batches processed
# 1005/3019 total batches processed
# 1006/3019 total batches processed
# 1007/3019 total batches processed
# 1008/3019 total batches processed
# 1009/3019 total batches processed
# 1010/3019 total batches processed
# 1011/3019 total batches processed
# 1012/3019 total batches processed
# 1013/3019 total batches processed
# 1014/3019 total batches processed
# 1015/3019 total batches processed
# 1016/3019 total batches processed
# 1017/3019 total batches processed
# 1018/3019 total batches processed
# 1019/3019 total batches processed
# 1020/3019 total batches processed
# 1021/3019 total batches processed
# 1022/3019 total batches processed
# 1023/3019 total batches processed
# 1024/3019 total batches processed
# 1025/3019 total batches processed
# 1026/3019 total batches processed
# 1027/3019 total batches processed
# 1028/3019 total batches processed
# 1029/3019 total batches processed
# 1030/3019 total batches processed
# 1031/3019 total batches processed
# 1032/3019 total batches processed
# 1033/3019 total batches processed
# 1034/3019 total batches processed
# 1035/3019 total batches processed
# 1036/3019 total batches processed
# 1037/3019 total batches processed
# 1038/3019 total batches processed
# 1039/3019 total batches processed
# 1040/3019 total batches processed
# 1041/3019 total batches processed
# 1042/3019 total batches processed
# 1043/3019 total batches processed
# 1044/3019 total batches processed
# 1045/3019 total batches processed
# 1046/3019 total batches processed
# 1047/3019 total batches processed
# 1048/3019 total batches processed
# 1049/3019 total batches processed
# 1050/3019 total batches processed
# 1051/3019 total batches processed
# 1052/3019 total batches processed
# 1053/3019 total batches processed
# 1054/3019 total batches processed
# 1055/3019 total batches processed
# 1056/3019 total batches processed
# 1057/3019 total batches processed
# 1058/3019 total batches processed
# 1059/3019 total batches processed
# 1060/3019 total batches processed
# 1061/3019 total batches processed
# 1062/3019 total batches processed
# 1063/3019 total batches processed
# 1064/3019 total batches processed
# 1065/3019 total batches processed
# 1066/3019 total batches processed
# 1067/3019 total batches processed
# 1068/3019 total batches processed
# 1069/3019 total batches processed
# 1070/3019 total batches processed
# 1071/3019 total batches processed
# 1072/3019 total batches processed
# 1073/3019 total batches processed
# 1074/3019 total batches processed
# 1075/3019 total batches processed
# 1076/3019 total batches processed
# 1077/3019 total batches processed
# 1078/3019 total batches processed
# 1079/3019 total batches processed
# 1080/3019 total batches processed
# 1081/3019 total batches processed
# 1082/3019 total batches processed
# 1083/3019 total batches processed
# 1084/3019 total batches processed
# 1085/3019 total batches processed
# 1086/3019 total batches processed
# 1087/3019 total batches processed
# 1088/3019 total batches processed
# 1089/3019 total batches processed
# 1090/3019 total batches processed
# 1091/3019 total batches processed
# 1092/3019 total batches processed
# 1093/3019 total batches processed
# 1094/3019 total batches processed
# 1095/3019 total batches processed
# 1096/3019 total batches processed
# 1097/3019 total batches processed
# 1098/3019 total batches processed
# 1099/3019 total batches processed
# 1100/3019 total batches processed
# 1101/3019 total batches processed
# 1102/3019 total batches processed
# 1103/3019 total batches processed
# 1104/3019 total batches processed
# 1105/3019 total batches processed
# 1106/3019 total batches processed
# 1107/3019 total batches processed
# 1108/3019 total batches processed
# 1109/3019 total batches processed
# 1110/3019 total batches processed
# 1111/3019 total batches processed
# 1112/3019 total batches processed
# 1113/3019 total batches processed
# 1114/3019 total batches processed
# 1115/3019 total batches processed
# 1116/3019 total batches processed
# 1117/3019 total batches processed
# 1118/3019 total batches processed
# 1119/3019 total batches processed
# 1120/3019 total batches processed
# 1121/3019 total batches processed
# 1122/3019 total batches processed
# 1123/3019 total batches processed
# 1124/3019 total batches processed
# 1125/3019 total batches processed
# 1126/3019 total batches processed
# 1127/3019 total batches processed
# 1128/3019 total batches processed
# 1129/3019 total batches processed
# 1130/3019 total batches processed
# 1131/3019 total batches processed
# 1132/3019 total batches processed
# 1133/3019 total batches processed
# 1134/3019 total batches processed
# 1135/3019 total batches processed
# 1136/3019 total batches processed
# 1137/3019 total batches processed
# 1138/3019 total batches processed
# 1139/3019 total batches processed
# 1140/3019 total batches processed
# 1141/3019 total batches processed
# 1142/3019 total batches processed
# 1143/3019 total batches processed
# 1144/3019 total batches processed
# 1145/3019 total batches processed
# 1146/3019 total batches processed
# 1147/3019 total batches processed
# 1148/3019 total batches processed
# 1149/3019 total batches processed
# 1150/3019 total batches processed
# 1151/3019 total batches processed
# 1152/3019 total batches processed
# 1153/3019 total batches processed
# 1154/3019 total batches processed
# 1155/3019 total batches processed
# 1156/3019 total batches processed
# 1157/3019 total batches processed
# 1158/3019 total batches processed
# 1159/3019 total batches processed
# 1160/3019 total batches processed
# 1161/3019 total batches processed
# 1162/3019 total batches processed
# 1163/3019 total batches processed
# 1164/3019 total batches processed
# 1165/3019 total batches processed
# 1166/3019 total batches processed
# 1167/3019 total batches processed
# 1168/3019 total batches processed
# 1169/3019 total batches processed
# 1170/3019 total batches processed
# 1171/3019 total batches processed
# 1172/3019 total batches processed
# 1173/3019 total batches processed
# 1174/3019 total batches processed
# 1175/3019 total batches processed
# 1176/3019 total batches processed
# 1177/3019 total batches processed
# 1178/3019 total batches processed
# 1179/3019 total batches processed
# 1180/3019 total batches processed
# 1181/3019 total batches processed
# 1182/3019 total batches processed
# 1183/3019 total batches processed
# 1184/3019 total batches processed
# 1185/3019 total batches processed
# 1186/3019 total batches processed
# 1187/3019 total batches processed
# 1188/3019 total batches processed
# 1189/3019 total batches processed
# 1190/3019 total batches processed
# 1191/3019 total batches processed
# 1192/3019 total batches processed
# 1193/3019 total batches processed
# 1194/3019 total batches processed
# 1195/3019 total batches processed
# 1196/3019 total batches processed
# 1197/3019 total batches processed
# 1198/3019 total batches processed
# 1199/3019 total batches processed
# 1200/3019 total batches processed
# 1201/3019 total batches processed
# 1202/3019 total batches processed
# 1203/3019 total batches processed
# 1204/3019 total batches processed
# 1205/3019 total batches processed
# 1206/3019 total batches processed
# 1207/3019 total batches processed
# 1208/3019 total batches processed
# 1209/3019 total batches processed
# 1210/3019 total batches processed
# 1211/3019 total batches processed
# 1212/3019 total batches processed
# 1213/3019 total batches processed
# 1214/3019 total batches processed
# 1215/3019 total batches processed
# 1216/3019 total batches processed
# 1217/3019 total batches processed
# 1218/3019 total batches processed
# 1219/3019 total batches processed
# 1220/3019 total batches processed
# 1221/3019 total batches processed
# 1222/3019 total batches processed
# 1223/3019 total batches processed
# 1224/3019 total batches processed
# 1225/3019 total batches processed
# 1226/3019 total batches processed
# 1227/3019 total batches processed
# 1228/3019 total batches processed
# 1229/3019 total batches processed
# 1230/3019 total batches processed
# 1231/3019 total batches processed
# 1232/3019 total batches processed
# 1233/3019 total batches processed
# 1234/3019 total batches processed
# 1235/3019 total batches processed
# 1236/3019 total batches processed
# 1237/3019 total batches processed
# 1238/3019 total batches processed
# 1239/3019 total batches processed
# 1240/3019 total batches processed
# 1241/3019 total batches processed
# 1242/3019 total batches processed
# 1243/3019 total batches processed
# 1244/3019 total batches processed
# 1245/3019 total batches processed
# 1246/3019 total batches processed
# 1247/3019 total batches processed
# 1248/3019 total batches processed
# 1249/3019 total batches processed
# 1250/3019 total batches processed
# 1251/3019 total batches processed
# 1252/3019 total batches processed
# 1253/3019 total batches processed
# 1254/3019 total batches processed
# 1255/3019 total batches processed
# 1256/3019 total batches processed
# 1257/3019 total batches processed
# 1258/3019 total batches processed
# 1259/3019 total batches processed
# 1260/3019 total batches processed
# 1261/3019 total batches processed
# 1262/3019 total batches processed
# 1263/3019 total batches processed
# 1264/3019 total batches processed
# 1265/3019 total batches processed
# 1266/3019 total batches processed
# 1267/3019 total batches processed
# 1268/3019 total batches processed
# 1269/3019 total batches processed
# 1270/3019 total batches processed
# 1271/3019 total batches processed
# 1272/3019 total batches processed
# 1273/3019 total batches processed
# 1274/3019 total batches processed
# 1275/3019 total batches processed
# 1276/3019 total batches processed
# 1277/3019 total batches processed
# 1278/3019 total batches processed
# 1279/3019 total batches processed
# 1280/3019 total batches processed
# 1281/3019 total batches processed
# 1282/3019 total batches processed
# 1283/3019 total batches processed
# 1284/3019 total batches processed
# 1285/3019 total batches processed
# 1286/3019 total batches processed
# 1287/3019 total batches processed
# 1288/3019 total batches processed
# 1289/3019 total batches processed
# 1290/3019 total batches processed
# 1291/3019 total batches processed
# 1292/3019 total batches processed
# 1293/3019 total batches processed
# 1294/3019 total batches processed
# 1295/3019 total batches processed
# 1296/3019 total batches processed
# 1297/3019 total batches processed
# 1298/3019 total batches processed
# 1299/3019 total batches processed
# 1300/3019 total batches processed
# 1301/3019 total batches processed
# 1302/3019 total batches processed
# 1303/3019 total batches processed
# 1304/3019 total batches processed
# 1305/3019 total batches processed
# 1306/3019 total batches processed
# 1307/3019 total batches processed
# 1308/3019 total batches processed
# 1309/3019 total batches processed
# 1310/3019 total batches processed
# 1311/3019 total batches processed
# 1312/3019 total batches processed
# 1313/3019 total batches processed
# 1314/3019 total batches processed
# 1315/3019 total batches processed
# 1316/3019 total batches processed
# 1317/3019 total batches processed
# 1318/3019 total batches processed
# 1319/3019 total batches processed
# 1320/3019 total batches processed
# 1321/3019 total batches processed
# 1322/3019 total batches processed
# 1323/3019 total batches processed
# 1324/3019 total batches processed
# 1325/3019 total batches processed
# 1326/3019 total batches processed
# 1327/3019 total batches processed
# 1328/3019 total batches processed
# 1329/3019 total batches processed
# 1330/3019 total batches processed
# 1331/3019 total batches processed
# 1332/3019 total batches processed
# 1333/3019 total batches processed
# 1334/3019 total batches processed
# 1335/3019 total batches processed
# 1336/3019 total batches processed
# 1337/3019 total batches processed
# 1338/3019 total batches processed
# 1339/3019 total batches processed
# 1340/3019 total batches processed
# 1341/3019 total batches processed
# 1342/3019 total batches processed
# 1343/3019 total batches processed
# 1344/3019 total batches processed
# 1345/3019 total batches processed
# 1346/3019 total batches processed
# 1347/3019 total batches processed
# 1348/3019 total batches processed
# 1349/3019 total batches processed
# 1350/3019 total batches processed
# 1351/3019 total batches processed
# 1352/3019 total batches processed
# 1353/3019 total batches processed
# 1354/3019 total batches processed
# 1355/3019 total batches processed
# 1356/3019 total batches processed
# 1357/3019 total batches processed
# 1358/3019 total batches processed
# 1359/3019 total batches processed
# 1360/3019 total batches processed
# 1361/3019 total batches processed
# 1362/3019 total batches processed
# 1363/3019 total batches processed
# 1364/3019 total batches processed
# 1365/3019 total batches processed
# 1366/3019 total batches processed
# 1367/3019 total batches processed
# 1368/3019 total batches processed
# 1369/3019 total batches processed
# 1370/3019 total batches processed
# 1371/3019 total batches processed
# 1372/3019 total batches processed
# 1373/3019 total batches processed
# 1374/3019 total batches processed
# 1375/3019 total batches processed
# 1376/3019 total batches processed
# 1377/3019 total batches processed
# 1378/3019 total batches processed
# 1379/3019 total batches processed
# 1380/3019 total batches processed
# 1381/3019 total batches processed
# 1382/3019 total batches processed
# 1383/3019 total batches processed
# 1384/3019 total batches processed
# 1385/3019 total batches processed
# 1386/3019 total batches processed
# 1387/3019 total batches processed
# 1388/3019 total batches processed
# 1389/3019 total batches processed
# 1390/3019 total batches processed
# 1391/3019 total batches processed
# 1392/3019 total batches processed
# 1393/3019 total batches processed
# 1394/3019 total batches processed
# 1395/3019 total batches processed
# 1396/3019 total batches processed
# 1397/3019 total batches processed
# 1398/3019 total batches processed
# 1399/3019 total batches processed
# 1400/3019 total batches processed
# 1401/3019 total batches processed
# 1402/3019 total batches processed
# 1403/3019 total batches processed
# 1404/3019 total batches processed
# 1405/3019 total batches processed
# 1406/3019 total batches processed
# 1407/3019 total batches processed
# 1408/3019 total batches processed
# 1409/3019 total batches processed
# 1410/3019 total batches processed
# 1411/3019 total batches processed
# 1412/3019 total batches processed
# 1413/3019 total batches processed
# 1414/3019 total batches processed
# 1415/3019 total batches processed
# 1416/3019 total batches processed
# 1417/3019 total batches processed
# 1418/3019 total batches processed
# 1419/3019 total batches processed
# 1420/3019 total batches processed
# 1421/3019 total batches processed
# 1422/3019 total batches processed
# 1423/3019 total batches processed
# 1424/3019 total batches processed
# 1425/3019 total batches processed
# 1426/3019 total batches processed
# 1427/3019 total batches processed
# 1428/3019 total batches processed
# 1429/3019 total batches processed
# 1430/3019 total batches processed
# 1431/3019 total batches processed
# 1432/3019 total batches processed
# 1433/3019 total batches processed
# 1434/3019 total batches processed
# 1435/3019 total batches processed
# 1436/3019 total batches processed
# 1437/3019 total batches processed
# 1438/3019 total batches processed
# 1439/3019 total batches processed
# 1440/3019 total batches processed
# 1441/3019 total batches processed
# 1442/3019 total batches processed
# ...
# 2748/3019 total batches processed
# 2749/3019 total batches processed
# 2750/3019 total batches processed
# 2751/3019 total batches processed
# 2752/3019 total batches processed
# 2753/3019 total batches processed
# 2754/3019 total batches processed
# 2755/3019 total batches processed
# 2756/3019 total batches processed
# 2757/3019 total batches processed
# 2758/3019 total batches processed
# 2759/3019 total batches processed
# 2760/3019 total batches processed
# 2761/3019 total batches processed
# 2762/3019 total batches processed
# 2763/3019 total batches processed
# 2764/3019 total batches processed
# 2765/3019 total batches processed
# 2766/3019 total batches processed
# 2767/3019 total batches processed
# 2768/3019 total batches processed
# 2769/3019 total batches processed
# 2770/3019 total batches processed
# 2771/3019 total batches processed
# 2772/3019 total batches processed
# 2773/3019 total batches processed
# 2774/3019 total batches processed
# 2775/3019 total batches processed
# 2776/3019 total batches processed
# 2777/3019 total batches processed
# 2778/3019 total batches processed
# 2779/3019 total batches processed
# 2780/3019 total batches processed
# 2781/3019 total batches processed
# 2782/3019 total batches processed
# 2783/3019 total batches processed
# 2784/3019 total batches processed
# 2785/3019 total batches processed
# 2786/3019 total batches processed
# 2787/3019 total batches processed
# 2788/3019 total batches processed
# 2789/3019 total batches processed
# 2790/3019 total batches processed
# 2791/3019 total batches processed
# 2792/3019 total batches processed
# 2793/3019 total batches processed
# 2794/3019 total batches processed
# 2795/3019 total batches processed
# 2796/3019 total batches processed
# 2797/3019 total batches processed
# 2798/3019 total batches processed
# 2799/3019 total batches processed
# 2800/3019 total batches processed
# 2801/3019 total batches processed
# 2802/3019 total batches processed
# 2803/3019 total batches processed
# 2804/3019 total batches processed
# 2805/3019 total batches processed
# 2806/3019 total batches processed
# 2807/3019 total batches processed
# 2808/3019 total batches processed
# 2809/3019 total batches processed
# 2810/3019 total batches processed
# 2811/3019 total batches processed
# 2812/3019 total batches processed
# 2813/3019 total batches processed
# 2814/3019 total batches processed
# 2815/3019 total batches processed
# 2816/3019 total batches processed
# 2817/3019 total batches processed
# 2818/3019 total batches processed
# 2819/3019 total batches processed
# 2820/3019 total batches processed
# 2821/3019 total batches processed
# 2822/3019 total batches processed
# 2823/3019 total batches processed
# 2824/3019 total batches processed
# 2825/3019 total batches processed
# 2826/3019 total batches processed
# 2827/3019 total batches processed
# 2828/3019 total batches processed
# 2829/3019 total batches processed
# 2830/3019 total batches processed
# 2831/3019 total batches processed
# 2832/3019 total batches processed
# 2833/3019 total batches processed
# 2834/3019 total batches processed
# 2835/3019 total batches processed
# 2836/3019 total batches processed
# 2837/3019 total batches processed
# 2838/3019 total batches processed
# 2839/3019 total batches processed
# 2840/3019 total batches processed
# 2841/3019 total batches processed
# 2842/3019 total batches processed
# 2843/3019 total batches processed
# 2844/3019 total batches processed
# 2845/3019 total batches processed
# 2846/3019 total batches processed
# 2847/3019 total batches processed
# 2848/3019 total batches processed
# 2849/3019 total batches processed
# 2850/3019 total batches processed
# 2851/3019 total batches processed
# 2852/3019 total batches processed
# 2853/3019 total batches processed
# 2854/3019 total batches processed
# 2855/3019 total batches processed
# 2856/3019 total batches processed
# 2857/3019 total batches processed
# 2858/3019 total batches processed
# 2859/3019 total batches processed
# 2860/3019 total batches processed
# 2861/3019 total batches processed
# 2862/3019 total batches processed
# 2863/3019 total batches processed
# 2864/3019 total batches processed
# 2865/3019 total batches processed
# 2866/3019 total batches processed
# 2867/3019 total batches processed
# 2868/3019 total batches processed
# 2869/3019 total batches processed
# 2870/3019 total batches processed
# 2871/3019 total batches processed
# 2872/3019 total batches processed
# 2873/3019 total batches processed
# 2874/3019 total batches processed
# 2875/3019 total batches processed
# 2876/3019 total batches processed
# 2877/3019 total batches processed
# 2878/3019 total batches processed
# 2879/3019 total batches processed
# 2880/3019 total batches processed
# 2881/3019 total batches processed
# 2882/3019 total batches processed
# 2883/3019 total batches processed
# 2884/3019 total batches processed
# 2885/3019 total batches processed
# 2886/3019 total batches processed
# 2887/3019 total batches processed
# 2888/3019 total batches processed
# 2889/3019 total batches processed
# 2890/3019 total batches processed
# 2891/3019 total batches processed
# 2892/3019 total batches processed
# 2893/3019 total batches processed
# 2894/3019 total batches processed
# 2895/3019 total batches processed
# 2896/3019 total batches processed
# 2897/3019 total batches processed
# 2898/3019 total batches processed
# 2899/3019 total batches processed
# 2900/3019 total batches processed
# 2901/3019 total batches processed
# 2902/3019 total batches processed
# 2903/3019 total batches processed
# 2904/3019 total batches processed
# 2905/3019 total batches processed
# 2906/3019 total batches processed
# 2907/3019 total batches processed
# 2908/3019 total batches processed
# 2909/3019 total batches processed
# 2910/3019 total batches processed
# 2911/3019 total batches processed
# 2912/3019 total batches processed
# 2913/3019 total batches processed
# 2914/3019 total batches processed
# 2915/3019 total batches processed
# 2916/3019 total batches processed
# 2917/3019 total batches processed
# 2918/3019 total batches processed
# 2919/3019 total batches processed
# 2920/3019 total batches processed
# 2921/3019 total batches processed
# 2922/3019 total batches processed
# 2923/3019 total batches processed
# 2924/3019 total batches processed
# 2925/3019 total batches processed
# 2926/3019 total batches processed
# 2927/3019 total batches processed
# 2928/3019 total batches processed
# 2929/3019 total batches processed
# 2930/3019 total batches processed
# 2931/3019 total batches processed
# 2932/3019 total batches processed
# 2933/3019 total batches processed
# 2934/3019 total batches processed
# 2935/3019 total batches processed
# 2936/3019 total batches processed
# 2937/3019 total batches processed
# 2938/3019 total batches processed
# 2939/3019 total batches processed
# 2940/3019 total batches processed
# 2941/3019 total batches processed
# 2942/3019 total batches processed
# 2943/3019 total batches processed
# 2944/3019 total batches processed
# 2945/3019 total batches processed
# 2946/3019 total batches processed
# 2947/3019 total batches processed
# 2948/3019 total batches processed
# 2949/3019 total batches processed
# 2950/3019 total batches processed
# 2951/3019 total batches processed
# 2952/3019 total batches processed
# 2953/3019 total batches processed
# 2954/3019 total batches processed
# 2955/3019 total batches processed
# 2956/3019 total batches processed
# 2957/3019 total batches processed
# 2958/3019 total batches processed
# 2959/3019 total batches processed
# 2960/3019 total batches processed
# 2961/3019 total batches processed
# 2962/3019 total batches processed
# 2963/3019 total batches processed
# 2964/3019 total batches processed
# 2965/3019 total batches processed
# 2966/3019 total batches processed
# 2967/3019 total batches processed
# 2968/3019 total batches processed
# 2969/3019 total batches processed
# 2970/3019 total batches processed
# 2971/3019 total batches processed
# 2972/3019 total batches processed
# 2973/3019 total batches processed
# 2974/3019 total batches processed
# 2975/3019 total batches processed
# 2976/3019 total batches processed
# 2977/3019 total batches processed
# 2978/3019 total batches processed
# 2979/3019 total batches processed
# 2980/3019 total batches processed
# 2981/3019 total batches processed
# 2982/3019 total batches processed
# 2983/3019 total batches processed
# 2984/3019 total batches processed
# 2985/3019 total batches processed
# 2986/3019 total batches processed
# 2987/3019 total batches processed
# 2988/3019 total batches processed
# 2989/3019 total batches processed
# 2990/3019 total batches processed
# 2991/3019 total batches processed
# 2992/3019 total batches processed
# 2993/3019 total batches processed
# 2994/3019 total batches processed
# 2995/3019 total batches processed
# 2996/3019 total batches processed
# 2997/3019 total batches processed
# 2998/3019 total batches processed
# 2999/3019 total batches processed
# 3000/3019 total batches processed
# 3001/3019 total batches processed
# 3002/3019 total batches processed
# 3003/3019 total batches processed
# 3004/3019 total batches processed
# 3005/3019 total batches processed
# 3006/3019 total batches processed
# 3007/3019 total batches processed
# 3008/3019 total batches processed
# 3009/3019 total batches processed
# 3010/3019 total batches processed
# 3011/3019 total batches processed
# 3012/3019 total batches processed
# 3013/3019 total batches processed
# 3014/3019 total batches processed
# 3015/3019 total batches processed
# 3016/3019 total batches processed
# 3017/3019 total batches processed
# 3018/3019 total batches processed
# 3019/3019 total batches processed
# 3020/3019 total batches processed
#
# Val Batches processing...
# 1/201 total batches processed
# 2/201 total batches processed
# 3/201 total batches processed
# 4/201 total batches processed
# 5/201 total batches processed
# 6/201 total batches processed
# 7/201 total batches processed
# 8/201 total batches processed
# 9/201 total batches processed
# 10/201 total batches processed
# 11/201 total batches processed
# 12/201 total batches processed
# 13/201 total batches processed
# 14/201 total batches processed
# 15/201 total batches processed
# 16/201 total batches processed
# 17/201 total batches processed
# 18/201 total batches processed
# 19/201 total batches processed
# 20/201 total batches processed
# 21/201 total batches processed
# 22/201 total batches processed
# 23/201 total batches processed
# 24/201 total batches processed
# 25/201 total batches processed
# 26/201 total batches processed
# 27/201 total batches processed
# 28/201 total batches processed
# 29/201 total batches processed
# 30/201 total batches processed
# 31/201 total batches processed
# 32/201 total batches processed
# 33/201 total batches processed
# 34/201 total batches processed
# 35/201 total batches processed
# 36/201 total batches processed
# 37/201 total batches processed
# 38/201 total batches processed
# 39/201 total batches processed
# 40/201 total batches processed
# 41/201 total batches processed
# 42/201 total batches processed
# 43/201 total batches processed
# 44/201 total batches processed
# 45/201 total batches processed
# 46/201 total batches processed
# 47/201 total batches processed
# 48/201 total batches processed
# 49/201 total batches processed
# 50/201 total batches processed
# 51/201 total batches processed
# 52/201 total batches processed
# 53/201 total batches processed
# 54/201 total batches processed
# 55/201 total batches processed
# 56/201 total batches processed
# 57/201 total batches processed
# 58/201 total batches processed
# 59/201 total batches processed
# 60/201 total batches processed
# 61/201 total batches processed
# 62/201 total batches processed
# 63/201 total batches processed
# 64/201 total batches processed
# 65/201 total batches processed
# 66/201 total batches processed
# 67/201 total batches processed
# 68/201 total batches processed
# 69/201 total batches processed
# 70/201 total batches processed
# 71/201 total batches processed
# 72/201 total batches processed
# 73/201 total batches processed
# 74/201 total batches processed
# 75/201 total batches processed
# 76/201 total batches processed
# 77/201 total batches processed
# 78/201 total batches processed
# 79/201 total batches processed
# 80/201 total batches processed
# 81/201 total batches processed
# 82/201 total batches processed
# 83/201 total batches processed
# 84/201 total batches processed
# 85/201 total batches processed
# 86/201 total batches processed
# 87/201 total batches processed
# 88/201 total batches processed
# 89/201 total batches processed
# 90/201 total batches processed
# 91/201 total batches processed
# 92/201 total batches processed
# 93/201 total batches processed
# 94/201 total batches processed
# 95/201 total batches processed
# 96/201 total batches processed
# 97/201 total batches processed
# 98/201 total batches processed
# 99/201 total batches processed
# 100/201 total batches processed
# 101/201 total batches processed
# 102/201 total batches processed
# 103/201 total batches processed
# 104/201 total batches processed
# 105/201 total batches processed
# 106/201 total batches processed
# 107/201 total batches processed
# 108/201 total batches processed
# 109/201 total batches processed
# 110/201 total batches processed
# 111/201 total batches processed
# 112/201 total batches processed
# 113/201 total batches processed
# 114/201 total batches processed
# 115/201 total batches processed
# 116/201 total batches processed
# 117/201 total batches processed
# 118/201 total batches processed
# 119/201 total batches processed
# 120/201 total batches processed
# 121/201 total batches processed
# 122/201 total batches processed
# 123/201 total batches processed
# 124/201 total batches processed
# 125/201 total batches processed
# 126/201 total batches processed
# 127/201 total batches processed
# 128/201 total batches processed
# 129/201 total batches processed
# 130/201 total batches processed
# 131/201 total batches processed
# 132/201 total batches processed
# 133/201 total batches processed
# 134/201 total batches processed
# 135/201 total batches processed
# 136/201 total batches processed
# 137/201 total batches processed
# 138/201 total batches processed
# 139/201 total batches processed
# 140/201 total batches processed
# 141/201 total batches processed
# 142/201 total batches processed
# 143/201 total batches processed
# 144/201 total batches processed
# 145/201 total batches processed
# 146/201 total batches processed
# 147/201 total batches processed
# 148/201 total batches processed
# 149/201 total batches processed
# 150/201 total batches processed
# 151/201 total batches processed
# 152/201 total batches processed
# 153/201 total batches processed
# 154/201 total batches processed
# 155/201 total batches processed
# 156/201 total batches processed
# 157/201 total batches processed
# 158/201 total batches processed
# 159/201 total batches processed
# 160/201 total batches processed
# 161/201 total batches processed
# 162/201 total batches processed
# 163/201 total batches processed
# 164/201 total batches processed
# 165/201 total batches processed
# 166/201 total batches processed
# 167/201 total batches processed
# 168/201 total batches processed
# 169/201 total batches processed
# 170/201 total batches processed
# 171/201 total batches processed
# 172/201 total batches processed
# 173/201 total batches processed
# 174/201 total batches processed
# 175/201 total batches processed
# 176/201 total batches processed
# 177/201 total batches processed
# 178/201 total batches processed
# 179/201 total batches processed
# 180/201 total batches processed
# 181/201 total batches processed
# 182/201 total batches processed
# 183/201 total batches processed
# 184/201 total batches processed
# 185/201 total batches processed
# 186/201 total batches processed
# 187/201 total batches processed
# 188/201 total batches processed
# 189/201 total batches processed
# 190/201 total batches processed
# 191/201 total batches processed
# 192/201 total batches processed
# 193/201 total batches processed
# 194/201 total batches processed
# 195/201 total batches processed
# 196/201 total batches processed
# 197/201 total batches processed
# 198/201 total batches processed
# 199/201 total batches processed
# 200/201 total batches processed
# 201/201 total batches processed
# 202/201 total batches processed
# Epoch : 1
# Loss : 158.01686163231878
#
# Train :
# PRECISION : 2.0903416985429808e-08
# RECALL : 1.7404742036956296e-05
# Epoches: 100%|██████████| 1/1 [2:05:10<00:00, 7510.37s/it]
# F1-SCORE : 4.1601595318151356e-08
#
# Val :
# PRECISION : 7.49388349229359e-08
# RECALL : 9.335237721828585e-06
# F1-SCORE : 1.4868410478452813e-07

# %%
resnet18_model.eval()

y_true_test, y_pred_test = torch.Tensor([]), torch.Tensor([])
y_true_test, y_pred_test = y_true_test.to(device), y_pred_test.to(device)

print('Test Batches processing...')

with torch.no_grad():
    for batch_index, batch in enumerate(test_dataloader, 0):

        images, categories = batch['img'], batch['category_id']
        images, categories = images.to(device), categories.to(device)

        outputs = resnet18_model(images)

        _, preds = torch.max(outputs,1)

        y_pred_test = torch.cat((y_pred_test, preds))
        y_true_test = torch.cat((y_true_test, categories))
        
        print(f'{batch_index + 1}/{num_of_batches_test} total batches processed')
        
#         break
        

        
print('Test : ')
print(f"PRECISION : {precision_score(y_true_test.cpu().numpy().astype(int), y_pred_test.cpu().numpy().astype(int), average='macro')}")
print(f"RECALL : {recall_score(y_true_test.cpu().numpy().astype(int), y_pred_test.cpu().numpy().astype(int), average='macro')}")
print(f"F1-SCORE : {f1_score(y_true_test.cpu().numpy().astype(int), y_pred_test.cpu().numpy().astype(int), average='macro')}")
print()
# Out:
# Test Batches processing...
# 1/805 total batches processed
# 2/805 total batches processed
# 3/805 total batches processed
# 4/805 total batches processed
# 5/805 total batches processed
# 6/805 total batches processed
# 7/805 total batches processed
# 8/805 total batches processed
# 9/805 total batches processed
# 10/805 total batches processed
# 11/805 total batches processed
# 12/805 total batches processed
# 13/805 total batches processed
# 14/805 total batches processed
# 15/805 total batches processed
# 16/805 total batches processed
# 17/805 total batches processed
# 18/805 total batches processed
# 19/805 total batches processed
# 20/805 total batches processed
# 21/805 total batches processed
# 22/805 total batches processed
# 23/805 total batches processed
# 24/805 total batches processed
# 25/805 total batches processed
# 26/805 total batches processed
# 27/805 total batches processed
# 28/805 total batches processed
# 29/805 total batches processed
# 30/805 total batches processed
# 31/805 total batches processed
# 32/805 total batches processed
# 33/805 total batches processed
# 34/805 total batches processed
# 35/805 total batches processed
# 36/805 total batches processed
# 37/805 total batches processed
# 38/805 total batches processed
# 39/805 total batches processed
# 40/805 total batches processed
# 41/805 total batches processed
# 42/805 total batches processed
# 43/805 total batches processed
# 44/805 total batches processed
# 45/805 total batches processed
# 46/805 total batches processed
# 47/805 total batches processed
# 48/805 total batches processed
# 49/805 total batches processed
# 50/805 total batches processed
# 51/805 total batches processed
# 52/805 total batches processed
# 53/805 total batches processed
# 54/805 total batches processed
# 55/805 total batches processed
# 56/805 total batches processed
# 57/805 total batches processed
# 58/805 total batches processed
# 59/805 total batches processed
# 60/805 total batches processed
# 61/805 total batches processed
# 62/805 total batches processed
# 63/805 total batches processed
# 64/805 total batches processed
# 65/805 total batches processed
# 66/805 total batches processed
# 67/805 total batches processed
# 68/805 total batches processed
# 69/805 total batches processed
# 70/805 total batches processed
# 71/805 total batches processed
# 72/805 total batches processed
# 73/805 total batches processed
# 74/805 total batches processed
# 75/805 total batches processed
# 76/805 total batches processed
# 77/805 total batches processed
# 78/805 total batches processed
# 79/805 total batches processed
# 80/805 total batches processed
# 81/805 total batches processed
# 82/805 total batches processed
# 83/805 total batches processed
# 84/805 total batches processed
# 85/805 total batches processed
# 86/805 total batches processed
# 87/805 total batches processed
# 88/805 total batches processed
# 89/805 total batches processed
# 90/805 total batches processed
# 91/805 total batches processed
# 92/805 total batches processed
# 93/805 total batches processed
# 94/805 total batches processed
# 95/805 total batches processed
# 96/805 total batches processed
# 97/805 total batches processed
# 98/805 total batches processed
# 99/805 total batches processed
# 100/805 total batches processed
# 101/805 total batches processed
# 102/805 total batches processed
# 103/805 total batches processed
# 104/805 total batches processed
# 105/805 total batches processed
# 106/805 total batches processed
# 107/805 total batches processed
# 108/805 total batches processed
# 109/805 total batches processed
# 110/805 total batches processed
# 111/805 total batches processed
# 112/805 total batches processed
# 113/805 total batches processed
# 114/805 total batches processed
# 115/805 total batches processed
# 116/805 total batches processed
# 117/805 total batches processed
# 118/805 total batches processed
# 119/805 total batches processed
# 120/805 total batches processed
# 121/805 total batches processed
# 122/805 total batches processed
# 123/805 total batches processed
# 124/805 total batches processed
# 125/805 total batches processed
# 126/805 total batches processed
# 127/805 total batches processed
# 128/805 total batches processed
# 129/805 total batches processed
# 130/805 total batches processed
# 131/805 total batches processed
# 132/805 total batches processed
# 133/805 total batches processed
# 134/805 total batches processed
# 135/805 total batches processed
# 136/805 total batches processed
# 137/805 total batches processed
# 138/805 total batches processed
# 139/805 total batches processed
# 140/805 total batches processed
# 141/805 total batches processed
# 142/805 total batches processed
# 143/805 total batches processed
# 144/805 total batches processed
# 145/805 total batches processed
# 146/805 total batches processed
# 147/805 total batches processed
# 148/805 total batches processed
# 149/805 total batches processed
# 150/805 total batches processed
# 151/805 total batches processed
# 152/805 total batches processed
# 153/805 total batches processed
# 154/805 total batches processed
# 155/805 total batches processed
# 156/805 total batches processed
# 157/805 total batches processed
# 158/805 total batches processed
# 159/805 total batches processed
# 160/805 total batches processed
# 161/805 total batches processed
# 162/805 total batches processed
# 163/805 total batches processed
# 164/805 total batches processed
# 165/805 total batches processed
# 166/805 total batches processed
# 167/805 total batches processed
# 168/805 total batches processed
# 169/805 total batches processed
# 170/805 total batches processed
# 171/805 total batches processed
# 172/805 total batches processed
# 173/805 total batches processed
# 174/805 total batches processed
# 175/805 total batches processed
# 176/805 total batches processed
# 177/805 total batches processed
# 178/805 total batches processed
# 179/805 total batches processed
# 180/805 total batches processed
# 181/805 total batches processed
# 182/805 total batches processed
# 183/805 total batches processed
# 184/805 total batches processed
# 185/805 total batches processed
# 186/805 total batches processed
# 187/805 total batches processed
# 188/805 total batches processed
# 189/805 total batches processed
# 190/805 total batches processed
# 191/805 total batches processed
# 192/805 total batches processed
# 193/805 total batches processed
# 194/805 total batches processed
# 195/805 total batches processed
# 196/805 total batches processed
# 197/805 total batches processed
# 198/805 total batches processed
# 199/805 total batches processed
# 200/805 total batches processed
# 201/805 total batches processed
# 202/805 total batches processed
# 203/805 total batches processed
# 204/805 total batches processed
# 205/805 total batches processed
# 206/805 total batches processed
# 207/805 total batches processed
# 208/805 total batches processed
# 209/805 total batches processed
# 210/805 total batches processed
# 211/805 total batches processed
# 212/805 total batches processed
# 213/805 total batches processed
# 214/805 total batches processed
# 215/805 total batches processed
# 216/805 total batches processed
# 217/805 total batches processed
# 218/805 total batches processed
# 219/805 total batches processed
# 220/805 total batches processed
# 221/805 total batches processed
# 222/805 total batches processed
# 223/805 total batches processed
# 224/805 total batches processed
# 225/805 total batches processed
# 226/805 total batches processed
# 227/805 total batches processed
# 228/805 total batches processed
# 229/805 total batches processed
# 230/805 total batches processed
# 231/805 total batches processed
# 232/805 total batches processed
# 233/805 total batches processed
# 234/805 total batches processed
# 235/805 total batches processed
# 236/805 total batches processed
# 237/805 total batches processed
# 238/805 total batches processed
# 239/805 total batches processed
# 240/805 total batches processed
# 241/805 total batches processed
# 242/805 total batches processed
# 243/805 total batches processed
# 244/805 total batches processed
# 245/805 total batches processed
# 246/805 total batches processed
# 247/805 total batches processed
# 248/805 total batches processed
# 249/805 total batches processed
# 250/805 total batches processed
# 251/805 total batches processed
# 252/805 total batches processed
# 253/805 total batches processed
# 254/805 total batches processed
# 255/805 total batches processed
# 256/805 total batches processed
# 257/805 total batches processed
# 258/805 total batches processed
# 259/805 total batches processed
# 260/805 total batches processed
# 261/805 total batches processed
# 262/805 total batches processed
# 263/805 total batches processed
# 264/805 total batches processed
# 265/805 total batches processed
# 266/805 total batches processed
# 267/805 total batches processed
# 268/805 total batches processed
# 269/805 total batches processed
# 270/805 total batches processed
# 271/805 total batches processed
# 272/805 total batches processed
# 273/805 total batches processed
# 274/805 total batches processed
# 275/805 total batches processed
# 276/805 total batches processed
# 277/805 total batches processed
# 278/805 total batches processed
# 279/805 total batches processed
# 280/805 total batches processed
# 281/805 total batches processed
# 282/805 total batches processed
# 283/805 total batches processed
# 284/805 total batches processed
# 285/805 total batches processed
# 286/805 total batches processed
# 287/805 total batches processed
# 288/805 total batches processed
# 289/805 total batches processed
# 290/805 total batches processed
# 291/805 total batches processed
# 292/805 total batches processed
# 293/805 total batches processed
# 294/805 total batches processed
# 295/805 total batches processed
# 296/805 total batches processed
# 297/805 total batches processed
# 298/805 total batches processed
# 299/805 total batches processed
# 300/805 total batches processed
# 301/805 total batches processed
# 302/805 total batches processed
# 303/805 total batches processed
# 304/805 total batches processed
# 305/805 total batches processed
# 306/805 total batches processed
# 307/805 total batches processed
# 308/805 total batches processed
# 309/805 total batches processed
# 310/805 total batches processed
# 311/805 total batches processed
# 312/805 total batches processed
# 313/805 total batches processed
# 314/805 total batches processed
# 315/805 total batches processed
# 316/805 total batches processed
# 317/805 total batches processed
# 318/805 total batches processed
# 319/805 total batches processed
# 320/805 total batches processed
# 321/805 total batches processed
# 322/805 total batches processed
# 323/805 total batches processed
# 324/805 total batches processed
# 325/805 total batches processed
# 326/805 total batches processed
# 327/805 total batches processed
# 328/805 total batches processed
# 329/805 total batches processed
# 330/805 total batches processed
# 331/805 total batches processed
# 332/805 total batches processed
# 333/805 total batches processed
# 334/805 total batches processed
# 335/805 total batches processed
# 336/805 total batches processed
# 337/805 total batches processed
# 338/805 total batches processed
# 339/805 total batches processed
# 340/805 total batches processed
# 341/805 total batches processed
# 342/805 total batches processed
# 343/805 total batches processed
# 344/805 total batches processed
# 345/805 total batches processed
# 346/805 total batches processed
# 347/805 total batches processed
# 348/805 total batches processed
# 349/805 total batches processed
# 350/805 total batches processed
# 351/805 total batches processed
# 352/805 total batches processed
# 353/805 total batches processed
# 354/805 total batches processed
# 355/805 total batches processed
# 356/805 total batches processed
# 357/805 total batches processed
# 358/805 total batches processed
# 359/805 total batches processed
# 360/805 total batches processed
# 361/805 total batches processed
# 362/805 total batches processed
# 363/805 total batches processed
# 364/805 total batches processed
# 365/805 total batches processed
# 366/805 total batches processed
# 367/805 total batches processed
# 368/805 total batches processed
# 369/805 total batches processed
# 370/805 total batches processed
# 371/805 total batches processed
# 372/805 total batches processed
# 373/805 total batches processed
# 374/805 total batches processed
# 375/805 total batches processed
# 376/805 total batches processed
# 377/805 total batches processed
# 378/805 total batches processed
# 379/805 total batches processed
# 380/805 total batches processed
# 381/805 total batches processed
# 382/805 total batches processed
# 383/805 total batches processed
# 384/805 total batches processed
# 385/805 total batches processed
# 386/805 total batches processed
# 387/805 total batches processed
# 388/805 total batches processed
# 389/805 total batches processed
# 390/805 total batches processed
# 391/805 total batches processed
# 392/805 total batches processed
# 393/805 total batches processed
# 394/805 total batches processed
# 395/805 total batches processed
# 396/805 total batches processed
# 397/805 total batches processed
# 398/805 total batches processed
# 399/805 total batches processed
# 400/805 total batches processed
# 401/805 total batches processed
# 402/805 total batches processed
# 403/805 total batches processed
# 404/805 total batches processed
# 405/805 total batches processed
# 406/805 total batches processed
# 407/805 total batches processed
# 408/805 total batches processed
# 409/805 total batches processed
# 410/805 total batches processed
# 411/805 total batches processed
# 412/805 total batches processed
# 413/805 total batches processed
# 414/805 total batches processed
# 415/805 total batches processed
# 416/805 total batches processed
# 417/805 total batches processed
# 418/805 total batches processed
# 419/805 total batches processed
# 420/805 total batches processed
# 421/805 total batches processed
# 422/805 total batches processed
# 423/805 total batches processed
# 424/805 total batches processed
# 425/805 total batches processed
# 426/805 total batches processed
# 427/805 total batches processed
# 428/805 total batches processed
# 429/805 total batches processed
# 430/805 total batches processed
# 431/805 total batches processed
# 432/805 total batches processed
# 433/805 total batches processed
# 434/805 total batches processed
# 435/805 total batches processed
# 436/805 total batches processed
# 437/805 total batches processed
# 438/805 total batches processed
# 439/805 total batches processed
# 440/805 total batches processed
# 441/805 total batches processed
# 442/805 total batches processed
# 443/805 total batches processed
# 444/805 total batches processed
# 445/805 total batches processed
# 446/805 total batches processed
# 447/805 total batches processed
# 448/805 total batches processed
# 449/805 total batches processed
# 450/805 total batches processed
# 451/805 total batches processed
# 452/805 total batches processed
# 453/805 total batches processed
# 454/805 total batches processed
# 455/805 total batches processed
# 456/805 total batches processed
# 457/805 total batches processed
# 458/805 total batches processed
# 459/805 total batches processed
# 460/805 total batches processed
# 461/805 total batches processed
# 462/805 total batches processed
# 463/805 total batches processed
# 464/805 total batches processed
# 465/805 total batches processed
# 466/805 total batches processed
# 467/805 total batches processed
# 468/805 total batches processed
# 469/805 total batches processed
# 470/805 total batches processed
# 471/805 total batches processed
# 472/805 total batches processed
# 473/805 total batches processed
# 474/805 total batches processed
# 475/805 total batches processed
# 476/805 total batches processed
# 477/805 total batches processed
# 478/805 total batches processed
# 479/805 total batches processed
# 480/805 total batches processed
# 481/805 total batches processed
# 482/805 total batches processed
# 483/805 total batches processed
# 484/805 total batches processed
# 485/805 total batches processed
# 486/805 total batches processed
# 487/805 total batches processed
# 488/805 total batches processed
# 489/805 total batches processed
# 490/805 total batches processed
# 491/805 total batches processed
# 492/805 total batches processed
# 493/805 total batches processed
# 494/805 total batches processed
# 495/805 total batches processed
# 496/805 total batches processed
# 497/805 total batches processed
# 498/805 total batches processed
# 499/805 total batches processed
# 500/805 total batches processed
# 501/805 total batches processed
# 502/805 total batches processed
# 503/805 total batches processed
# 504/805 total batches processed
# 505/805 total batches processed
# 506/805 total batches processed
# 507/805 total batches processed
# 508/805 total batches processed
# 509/805 total batches processed
# 510/805 total batches processed
# 511/805 total batches processed
# 512/805 total batches processed
# 513/805 total batches processed
# 514/805 total batches processed
# 515/805 total batches processed
# 516/805 total batches processed
# 517/805 total batches processed
# 518/805 total batches processed
# 519/805 total batches processed
# 520/805 total batches processed
# 521/805 total batches processed
# 522/805 total batches processed
# 523/805 total batches processed
# 524/805 total batches processed
# 525/805 total batches processed
# 526/805 total batches processed
# 527/805 total batches processed
# 528/805 total batches processed
# 529/805 total batches processed
# 530/805 total batches processed
# 531/805 total batches processed
# 532/805 total batches processed
# 533/805 total batches processed
# 534/805 total batches processed
# 535/805 total batches processed
# 536/805 total batches processed
# 537/805 total batches processed
# 538/805 total batches processed
# 539/805 total batches processed
# 540/805 total batches processed
# 541/805 total batches processed
# 542/805 total batches processed
# 543/805 total batches processed
# 544/805 total batches processed
# 545/805 total batches processed
# 546/805 total batches processed
# 547/805 total batches processed
# 548/805 total batches processed
# 549/805 total batches processed
# 550/805 total batches processed
# 551/805 total batches processed
# 552/805 total batches processed
# 553/805 total batches processed
# 554/805 total batches processed
# 555/805 total batches processed
# 556/805 total batches processed
# 557/805 total batches processed
# 558/805 total batches processed
# 559/805 total batches processed
# 560/805 total batches processed
# 561/805 total batches processed
# 562/805 total batches processed
# 563/805 total batches processed
# 564/805 total batches processed
# 565/805 total batches processed
# 566/805 total batches processed
# 567/805 total batches processed
# 568/805 total batches processed
# 569/805 total batches processed
# 570/805 total batches processed
# 571/805 total batches processed
# 572/805 total batches processed
# 573/805 total batches processed
# 574/805 total batches processed
# 575/805 total batches processed
# 576/805 total batches processed
# 577/805 total batches processed
# 578/805 total batches processed
# 579/805 total batches processed
# 580/805 total batches processed
# 581/805 total batches processed
# 582/805 total batches processed
# 583/805 total batches processed
# 584/805 total batches processed
# 585/805 total batches processed
# 586/805 total batches processed
# 587/805 total batches processed
# 588/805 total batches processed
# 589/805 total batches processed
# 590/805 total batches processed
# 591/805 total batches processed
# 592/805 total batches processed
# 593/805 total batches processed
# 594/805 total batches processed
# 595/805 total batches processed
# 596/805 total batches processed
# 597/805 total batches processed
# 598/805 total batches processed
# 599/805 total batches processed
# 600/805 total batches processed
# 601/805 total batches processed
# 602/805 total batches processed
# 603/805 total batches processed
# 604/805 total batches processed
# 605/805 total batches processed
# 606/805 total batches processed
# 607/805 total batches processed
# 608/805 total batches processed
# 609/805 total batches processed
# 610/805 total batches processed
# 611/805 total batches processed
# 612/805 total batches processed
# 613/805 total batches processed
# 614/805 total batches processed
# 615/805 total batches processed
# 616/805 total batches processed
# 617/805 total batches processed
# 618/805 total batches processed
# 619/805 total batches processed
# 620/805 total batches processed
# 621/805 total batches processed
# 622/805 total batches processed
# 623/805 total batches processed
# 624/805 total batches processed
# 625/805 total batches processed
# 626/805 total batches processed
# 627/805 total batches processed
# 628/805 total batches processed
# 629/805 total batches processed
# 630/805 total batches processed
# 631/805 total batches processed
# 632/805 total batches processed
# 633/805 total batches processed
# 634/805 total batches processed
# 635/805 total batches processed
# 636/805 total batches processed
# 637/805 total batches processed
# 638/805 total batches processed
# 639/805 total batches processed
# 640/805 total batches processed
# 641/805 total batches processed
# 642/805 total batches processed
# 643/805 total batches processed
# 644/805 total batches processed
# 645/805 total batches processed
# 646/805 total batches processed
# 647/805 total batches processed
# 648/805 total batches processed
# 649/805 total batches processed
# 650/805 total batches processed
# 651/805 total batches processed
# 652/805 total batches processed
# 653/805 total batches processed
# 654/805 total batches processed
# 655/805 total batches processed
# 656/805 total batches processed
# 657/805 total batches processed
# 658/805 total batches processed
# 659/805 total batches processed
# 660/805 total batches processed
# 661/805 total batches processed
# 662/805 total batches processed
# 663/805 total batches processed
# 664/805 total batches processed
# 665/805 total batches processed
# 666/805 total batches processed
# 667/805 total batches processed
# 668/805 total batches processed
# 669/805 total batches processed
# 670/805 total batches processed
# 671/805 total batches processed
# 672/805 total batches processed
# 673/805 total batches processed
# 674/805 total batches processed
# 675/805 total batches processed
# 676/805 total batches processed
# 677/805 total batches processed
# 678/805 total batches processed
# 679/805 total batches processed
# 680/805 total batches processed
# 681/805 total batches processed
# 682/805 total batches processed
# 683/805 total batches processed
# 684/805 total batches processed
# 685/805 total batches processed
# 686/805 total batches processed
# 687/805 total batches processed
# 688/805 total batches processed
# 689/805 total batches processed
# 690/805 total batches processed
# 691/805 total batches processed
# 692/805 total batches processed
# 693/805 total batches processed
# 694/805 total batches processed
# 695/805 total batches processed
# 696/805 total batches processed
# 697/805 total batches processed
# 698/805 total batches processed
# 699/805 total batches processed
# 700/805 total batches processed
# 701/805 total batches processed
# 702/805 total batches processed
# 703/805 total batches processed
# 704/805 total batches processed
# 705/805 total batches processed
# 706/805 total batches processed
# 707/805 total batches processed
# 708/805 total batches processed
# 709/805 total batches processed
# 710/805 total batches processed
# 711/805 total batches processed
# 712/805 total batches processed
# 713/805 total batches processed
# 714/805 total batches processed
# 715/805 total batches processed
# 716/805 total batches processed
# 717/805 total batches processed
# 718/805 total batches processed
# 719/805 total batches processed
# 720/805 total batches processed
# 721/805 total batches processed
# 722/805 total batches processed
# 723/805 total batches processed
# 724/805 total batches processed
# 725/805 total batches processed
# 726/805 total batches processed
# 727/805 total batches processed
# 728/805 total batches processed
# 729/805 total batches processed
# 730/805 total batches processed
# 731/805 total batches processed
# 732/805 total batches processed
# 733/805 total batches processed
# 734/805 total batches processed
# 735/805 total batches processed
# 736/805 total batches processed
# 737/805 total batches processed
# 738/805 total batches processed
# 739/805 total batches processed
# 740/805 total batches processed
# 741/805 total batches processed
# 742/805 total batches processed
# 743/805 total batches processed
# 744/805 total batches processed
# 745/805 total batches processed
# 746/805 total batches processed
# 747/805 total batches processed
# 748/805 total batches processed
# 749/805 total batches processed
# 750/805 total batches processed
# 751/805 total batches processed
# 752/805 total batches processed
# 753/805 total batches processed
# 754/805 total batches processed
# 755/805 total batches processed
# 756/805 total batches processed
# 757/805 total batches processed
# 758/805 total batches processed
# 759/805 total batches processed
# 760/805 total batches processed
# 761/805 total batches processed
# 762/805 total batches processed
# 763/805 total batches processed
# 764/805 total batches processed
# 765/805 total batches processed
# 766/805 total batches processed
# 767/805 total batches processed
# 768/805 total batches processed
# 769/805 total batches processed
# 770/805 total batches processed
# 771/805 total batches processed
# 772/805 total batches processed
# 773/805 total batches processed
# 774/805 total batches processed
# 775/805 total batches processed
# 776/805 total batches processed
# 777/805 total batches processed
# 778/805 total batches processed
# 779/805 total batches processed
# 780/805 total batches processed
# 781/805 total batches processed
# 782/805 total batches processed
# 783/805 total batches processed
# 784/805 total batches processed
# 785/805 total batches processed
# 786/805 total batches processed
# 787/805 total batches processed
# 788/805 total batches processed
# 789/805 total batches processed
# 790/805 total batches processed
# 791/805 total batches processed
# 792/805 total batches processed
# 793/805 total batches processed
# 794/805 total batches processed
# 795/805 total batches processed
# 796/805 total batches processed
# 797/805 total batches processed
# 798/805 total batches processed
# 799/805 total batches processed
# 800/805 total batches processed
# 801/805 total batches processed
# 802/805 total batches processed
# 803/805 total batches processed
# 804/805 total batches processed
# 805/805 total batches processed
# 806/805 total batches processed
# Test :
# PRECISION : 0.0
# RECALL : 0.0
# F1-SCORE : 0.0

# %% [markdown]
# # Submission

# %%
resnet18_model.eval()

y_subm = torch.Tensor([]).to(device)
ids = torch.Tensor([]).to(device)

print('Submission Batches processing...')


with torch.no_grad():
    for batch_index, batch in enumerate(test_subm_dataloader, 0):

        images, ids_batch = batch['img'], batch['id']
        images, ids_batch = images.to(device), ids_batch.to(device)

        outputs = resnet18_model(images)

        _, preds = torch.max(outputs,1)

        y_subm = torch.cat((y_subm, preds))
        ids = torch.cat((ids, ids_batch))
        
        print(f'{batch_index + 1}/{num_of_batches_subm} total batches processed')
        
#         break
        
        
y_subm_deprocessed = le_preprocessor.inverse_transform(y_subm.cpu().numpy().astype(int))


submission_df = pd.DataFrame({'Id' : ids.cpu().numpy(), 'Predicted' : y_subm_deprocessed})
submission_df.to_csv('/kaggle/working/resnet18_results_V2.csv')
# Out:
# Submission Batches processing...
# 1/540 total batches processed
# 2/540 total batches processed
# 3/540 total batches processed
# 4/540 total batches processed
# 5/540 total batches processed
# 6/540 total batches processed
# 7/540 total batches processed
# 8/540 total batches processed
# 9/540 total batches processed
# 10/540 total batches processed
# 11/540 total batches processed
# 12/540 total batches processed
# 13/540 total batches processed
# 14/540 total batches processed
# 15/540 total batches processed
# 16/540 total batches processed
# 17/540 total batches processed
# 18/540 total batches processed
# 19/540 total batches processed
# 20/540 total batches processed
# 21/540 total batches processed
# 22/540 total batches processed
# 23/540 total batches processed
# 24/540 total batches processed
# 25/540 total batches processed
# 26/540 total batches processed
# 27/540 total batches processed
# 28/540 total batches processed
# 29/540 total batches processed
# 30/540 total batches processed
# 31/540 total batches processed
# 32/540 total batches processed
# 33/540 total batches processed
# 34/540 total batches processed
# 35/540 total batches processed
# 36/540 total batches processed
# 37/540 total batches processed
# 38/540 total batches processed
# 39/540 total batches processed
# 40/540 total batches processed
# 41/540 total batches processed
# 42/540 total batches processed
# 43/540 total batches processed
# 44/540 total batches processed
# 45/540 total batches processed
# 46/540 total batches processed
# 47/540 total batches processed
# 48/540 total batches processed
# 49/540 total batches processed
# 50/540 total batches processed
# 51/540 total batches processed
# 52/540 total batches processed
# 53/540 total batches processed
# 54/540 total batches processed
# 55/540 total batches processed
# 56/540 total batches processed
# 57/540 total batches processed
# 58/540 total batches processed
# 59/540 total batches processed
# 60/540 total batches processed
# 61/540 total batches processed
# 62/540 total batches processed
# 63/540 total batches processed
# 64/540 total batches processed
# 65/540 total batches processed
# 66/540 total batches processed
# 67/540 total batches processed
# 68/540 total batches processed
# 69/540 total batches processed
# 70/540 total batches processed
# 71/540 total batches processed
# 72/540 total batches processed
# 73/540 total batches processed
# 74/540 total batches processed
# 75/540 total batches processed
# 76/540 total batches processed
# 77/540 total batches processed
# 78/540 total batches processed
# 79/540 total batches processed
# 80/540 total batches processed
# 81/540 total batches processed
# 82/540 total batches processed
# 83/540 total batches processed
# 84/540 total batches processed
# 85/540 total batches processed
# 86/540 total batches processed
# 87/540 total batches processed
# 88/540 total batches processed
# 89/540 total batches processed
# 90/540 total batches processed
# 91/540 total batches processed
# 92/540 total batches processed
# 93/540 total batches processed
# 94/540 total batches processed
# 95/540 total batches processed
# 96/540 total batches processed
# 97/540 total batches processed
# 98/540 total batches processed
# 99/540 total batches processed
# 100/540 total batches processed
# 101/540 total batches processed
# 102/540 total batches processed
# 103/540 total batches processed
# 104/540 total batches processed
# 105/540 total batches processed
# 106/540 total batches processed
# 107/540 total batches processed
# 108/540 total batches processed
# 109/540 total batches processed
# 110/540 total batches processed
# 111/540 total batches processed
# 112/540 total batches processed
# 113/540 total batches processed
# 114/540 total batches processed
# 115/540 total batches processed
# 116/540 total batches processed
# 117/540 total batches processed
# 118/540 total batches processed
# 119/540 total batches processed
# 120/540 total batches processed
# 121/540 total batches processed
# 122/540 total batches processed
# 123/540 total batches processed
# 124/540 total batches processed
# 125/540 total batches processed
# 126/540 total batches processed
# 127/540 total batches processed
# 128/540 total batches processed
# 129/540 total batches processed
# 130/540 total batches processed
# 131/540 total batches processed
# 132/540 total batches processed
# 133/540 total batches processed
# 134/540 total batches processed
# 135/540 total batches processed
# 136/540 total batches processed
# 137/540 total batches processed
# 138/540 total batches processed
# 139/540 total batches processed
# 140/540 total batches processed
# 141/540 total batches processed
# 142/540 total batches processed
# 143/540 total batches processed
# 144/540 total batches processed
# 145/540 total batches processed
# 146/540 total batches processed
# 147/540 total batches processed
# 148/540 total batches processed
# 149/540 total batches processed
# 150/540 total batches processed
# 151/540 total batches processed
# 152/540 total batches processed
# 153/540 total batches processed
# 154/540 total batches processed
# 155/540 total batches processed
# 156/540 total batches processed
# 157/540 total batches processed
# 158/540 total batches processed
# 159/540 total batches processed
# 160/540 total batches processed
# 161/540 total batches processed
# 162/540 total batches processed
# 163/540 total batches processed
# 164/540 total batches processed
# 165/540 total batches processed
# 166/540 total batches processed
# 167/540 total batches processed
# 168/540 total batches processed
# 169/540 total batches processed
# 170/540 total batches processed
# 171/540 total batches processed
# 172/540 total batches processed
# 173/540 total batches processed
# 174/540 total batches processed
# 175/540 total batches processed
# 176/540 total batches processed
# 177/540 total batches processed
# 178/540 total batches processed
# 179/540 total batches processed
# 180/540 total batches processed
# 181/540 total batches processed
# 182/540 total batches processed
# 183/540 total batches processed
# 184/540 total batches processed
# 185/540 total batches processed
# 186/540 total batches processed
# 187/540 total batches processed
# 188/540 total batches processed
# 189/540 total batches processed
# 190/540 total batches processed
# 191/540 total batches processed
# 192/540 total batches processed
# 193/540 total batches processed
# 194/540 total batches processed
# 195/540 total batches processed
# 196/540 total batches processed
# 197/540 total batches processed
# 198/540 total batches processed
# 199/540 total batches processed
# 200/540 total batches processed
# 201/540 total batches processed
# 202/540 total batches processed
# 203/540 total batches processed
# 204/540 total batches processed
# 205/540 total batches processed
# 206/540 total batches processed
# 207/540 total batches processed
# 208/540 total batches processed
# 209/540 total batches processed
# 210/540 total batches processed
# 211/540 total batches processed
# 212/540 total batches processed
# 213/540 total batches processed
# 214/540 total batches processed
# 215/540 total batches processed
# 216/540 total batches processed
# 217/540 total batches processed
# 218/540 total batches processed
# 219/540 total batches processed
# 220/540 total batches processed
# 221/540 total batches processed
# 222/540 total batches processed
# 223/540 total batches processed
# 224/540 total batches processed
# 225/540 total batches processed
# 226/540 total batches processed
# 227/540 total batches processed
# 228/540 total batches processed
# 229/540 total batches processed
# 230/540 total batches processed
# 231/540 total batches processed
# 232/540 total batches processed
# 233/540 total batches processed
# 234/540 total batches processed
# 235/540 total batches processed
# 236/540 total batches processed
# 237/540 total batches processed
# 238/540 total batches processed
# 239/540 total batches processed
# 240/540 total batches processed
# 241/540 total batches processed
# 242/540 total batches processed
# 243/540 total batches processed
# 244/540 total batches processed
# 245/540 total batches processed
# 246/540 total batches processed
# 247/540 total batches processed
# 248/540 total batches processed
# 249/540 total batches processed
# 250/540 total batches processed
# 251/540 total batches processed
# 252/540 total batches processed
# 253/540 total batches processed
# 254/540 total batches processed
# 255/540 total batches processed
# 256/540 total batches processed
# 257/540 total batches processed
# 258/540 total batches processed
# 259/540 total batches processed
# 260/540 total batches processed
# 261/540 total batches processed
# 262/540 total batches processed
# 263/540 total batches processed
# 264/540 total batches processed
# 265/540 total batches processed
# 266/540 total batches processed
# 267/540 total batches processed
# 268/540 total batches processed
# 269/540 total batches processed
# 270/540 total batches processed
# 271/540 total batches processed
# 272/540 total batches processed
# 273/540 total batches processed
# 274/540 total batches processed
# 275/540 total batches processed
# 276/540 total batches processed
# 277/540 total batches processed
# 278/540 total batches processed
# 279/540 total batches processed
# 280/540 total batches processed
# 281/540 total batches processed
# 282/540 total batches processed
# 283/540 total batches processed
# 284/540 total batches processed
# 285/540 total batches processed
# 286/540 total batches processed
# 287/540 total batches processed
# 288/540 total batches processed
# 289/540 total batches processed
# 290/540 total batches processed
# 291/540 total batches processed
# 292/540 total batches processed
# 293/540 total batches processed
# 294/540 total batches processed
# 295/540 total batches processed
# 296/540 total batches processed
# 297/540 total batches processed
# 298/540 total batches processed
# 299/540 total batches processed
# 300/540 total batches processed
# 301/540 total batches processed
# 302/540 total batches processed
# 303/540 total batches processed
# 304/540 total batches processed
# 305/540 total batches processed
# 306/540 total batches processed
# 307/540 total batches processed
# 308/540 total batches processed
# 309/540 total batches processed
# 310/540 total batches processed
# 311/540 total batches processed
# 312/540 total batches processed
# 313/540 total batches processed
# 314/540 total batches processed
# 315/540 total batches processed
# 316/540 total batches processed
# 317/540 total batches processed
# 318/540 total batches processed
# 319/540 total batches processed
# 320/540 total batches processed
# 321/540 total batches processed
# 322/540 total batches processed
# 323/540 total batches processed
# 324/540 total batches processed
# 325/540 total batches processed
# 326/540 total batches processed
# 327/540 total batches processed
# 328/540 total batches processed
# 329/540 total batches processed
# 330/540 total batches processed
# 331/540 total batches processed
# 332/540 total batches processed
# 333/540 total batches processed
# 334/540 total batches processed
# 335/540 total batches processed
# 336/540 total batches processed
# 337/540 total batches processed
# 338/540 total batches processed
# 339/540 total batches processed
# 340/540 total batches processed
# 341/540 total batches processed
# 342/540 total batches processed
# 343/540 total batches processed
# 344/540 total batches processed
# 345/540 total batches processed
# 346/540 total batches processed
# 347/540 total batches processed
# 348/540 total batches processed
# 349/540 total batches processed
# 350/540 total batches processed
# 351/540 total batches processed
# 352/540 total batches processed
# 353/540 total batches processed
# 354/540 total batches processed
# 355/540 total batches processed
# 356/540 total batches processed
# 357/540 total batches processed
# 358/540 total batches processed
# 359/540 total batches processed
# 360/540 total batches processed
# 361/540 total batches processed
# 362/540 total batches processed
# 363/540 total batches processed
# 364/540 total batches processed
# 365/540 total batches processed
# 366/540 total batches processed
# 367/540 total batches processed
# 368/540 total batches processed
# 369/540 total batches processed
# 370/540 total batches processed
# 371/540 total batches processed
# 372/540 total batches processed
# 373/540 total batches processed
# 374/540 total batches processed
# 375/540 total batches processed
# 376/540 total batches processed
# 377/540 total batches processed
# 378/540 total batches processed
# 379/540 total batches processed
# 380/540 total batches processed
# 381/540 total batches processed
# 382/540 total batches processed
# 383/540 total batches processed
# 384/540 total batches processed
# 385/540 total batches processed
# 386/540 total batches processed
# 387/540 total batches processed
# 388/540 total batches processed
# 389/540 total batches processed
# 390/540 total batches processed
# 391/540 total batches processed
# 392/540 total batches processed
# 393/540 total batches processed
# 394/540 total batches processed
# 395/540 total batches processed
# 396/540 total batches processed
# 397/540 total batches processed
# 398/540 total batches processed
# 399/540 total batches processed
# 400/540 total batches processed
# 401/540 total batches processed
# 402/540 total batches processed
# 403/540 total batches processed
# 404/540 total batches processed
# 405/540 total batches processed
# 406/540 total batches processed
# 407/540 total batches processed
# 408/540 total batches processed
# 409/540 total batches processed
# 410/540 total batches processed
# 411/540 total batches processed
# 412/540 total batches processed
# 413/540 total batches processed
# 414/540 total batches processed
# 415/540 total batches processed
# 416/540 total batches processed
# 417/540 total batches processed
# 418/540 total batches processed
# 419/540 total batches processed
# 420/540 total batches processed
# 421/540 total batches processed
# 422/540 total batches processed
# 423/540 total batches processed
# 424/540 total batches processed
# 425/540 total batches processed
# 426/540 total batches processed
# 427/540 total batches processed
# 428/540 total batches processed
# 429/540 total batches processed
# 430/540 total batches processed
# 431/540 total batches processed
# 432/540 total batches processed
# 433/540 total batches processed
# 434/540 total batches processed
# 435/540 total batches processed
# 436/540 total batches processed
# 437/540 total batches processed
# 438/540 total batches processed
# 439/540 total batches processed
# 440/540 total batches processed
# 441/540 total batches processed
# 442/540 total batches processed
# 443/540 total batches processed
# 444/540 total batches processed
# 445/540 total batches processed
# 446/540 total batches processed
# 447/540 total batches processed
# 448/540 total batches processed
# 449/540 total batches processed
# 450/540 total batches processed
# 451/540 total batches processed
# 452/540 total batches processed
# 453/540 total batches processed
# 454/540 total batches processed
# 455/540 total batches processed
# 456/540 total batches processed
# 457/540 total batches processed
# 458/540 total batches processed
# 459/540 total batches processed
# 460/540 total batches processed
# 461/540 total batches processed
# 462/540 total batches processed
# 463/540 total batches processed
# 464/540 total batches processed
# 465/540 total batches processed
# 466/540 total batches processed
# 467/540 total batches processed
# 468/540 total batches processed
# 469/540 total batches processed
# 470/540 total batches processed
# 471/540 total batches processed
# 472/540 total batches processed
# 473/540 total batches processed
# 474/540 total batches processed
# 475/540 total batches processed
# 476/540 total batches processed
# 477/540 total batches processed
# 478/540 total batches processed
# 479/540 total batches processed
# 480/540 total batches processed
# 481/540 total batches processed
# 482/540 total batches processed
# 483/540 total batches processed
# 484/540 total batches processed
# 485/540 total batches processed
# 486/540 total batches processed
# 487/540 total batches processed
# 488/540 total batches processed
# 489/540 total batches processed
# 490/540 total batches processed
# 491/540 total batches processed
# 492/540 total batches processed
# 493/540 total batches processed
# 494/540 total batches processed
# 495/540 total batches processed
# 496/540 total batches processed
# 497/540 total batches processed
# 498/540 total batches processed
# 499/540 total batches processed
# 500/540 total batches processed
# 501/540 total batches processed
# 502/540 total batches processed
# 503/540 total batches processed
# 504/540 total batches processed
# 505/540 total batches processed
# 506/540 total batches processed
# 507/540 total batches processed
# 508/540 total batches processed
# 509/540 total batches processed
# 510/540 total batches processed
# 511/540 total batches processed
# 512/540 total batches processed
# 513/540 total batches processed
# 514/540 total batches processed
# 515/540 total batches processed
# 516/540 total batches processed
# 517/540 total batches processed
# 518/540 total batches processed
# 519/540 total batches processed
# 520/540 total batches processed
# 521/540 total batches processed
# 522/540 total batches processed
# 523/540 total batches processed
# 524/540 total batches processed
# 525/540 total batches processed
# 526/540 total batches processed
# 527/540 total batches processed
# 528/540 total batches processed
# 529/540 total batches processed
# 530/540 total batches processed
# 531/540 total batches processed
# 532/540 total batches processed
# 533/540 total batches processed
# 534/540 total batches processed
# 535/540 total batches processed
# 536/540 total batches processed
# 537/540 total batches processed
# 538/540 total batches processed
# 539/540 total batches processed
# 540/540 total batches processed
# 541/540 total batches processed

# %%
len(submission_df)
# Out:
# 138292

# %%
submission_df = pd.DataFrame({'Id' : ids.cpu().numpy().astype(int), 'Predicted' : y_subm_deprocessed})
submission_df.to_csv('/kaggle/working/resnet18_results_V2.csv', header=True, index=False)

# %%
submission_df
# Out:
#             Id  Predicted
# 0       104891      16399
# 1        18029      24264
# 2        35151      16399
# 3       124144      14503
# 4        24649      16251
# ...        ...        ...
# 138287   32738      16399
# 138288   16804      14506
# 138289  113662      16399
# 138290   86100       9960
# 138291   28731      16399
#
# [138292 rows x 2 columns]

# %%
submission_example
# Out:
#             Id  Predicted
# 0            0          0
# 1            1          0
# 2            2          0
# 3            3          0
# 4            4          0
# ...        ...        ...
# 138287  138287          0
# 138288  138288          0
# 138289  138289          0
# 138290  138290          0
# 138291  138291          0
#
# [138292 rows x 2 columns]

# %%
submission_df['Predicted'].value_counts()
# Out:
# 16399    42688
# 9960     31344
# 3460      4413
# 27448     3601
# 1361      3353
#          ...
# 23471        1
# 31705        1
# 16478        1
# 16477        1
# 26637        1
# Name: Predicted, Length: 1050, dtype: int64
